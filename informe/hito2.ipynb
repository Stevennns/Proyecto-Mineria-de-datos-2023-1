# %% [markdown]
# ### <center>CC5205 - Minería de Datos</center>
# # <center>Multimodal Crisis Dataset - Hito 1</center>
# ##### <center>Grupo 1</center>
#
# <center>Integrantes: Jorge Araya, Jesús Cáceres, Agustín Cortés, Stevens Egli, Jessica Gajardo.</center>

# %% [markdown]
# Este trabajo se centra en la exploración del conjunto de datos de [Crisisnlp](https://crisisnlp.qcri.org/), específicamente el recurso número 5, constituido de tweets e imágenes relacionadas a siete grandes desastres naturales ocurridos en el año 2017:
# * Terremoto de México
# * Terremoto de Iraq
# * Huracán María
# * Huracán Irma
# * Huracán Harvey
# * Incendio de California
# * Inundación de Srilanka
#
# La motivación principal del grupo fue explorar los datos, intentando encontrar alguna tendencia de las características de los tweets relacionados a estos desastres en cuanto su magnitud y su difusión. Queremos descubirir qué aspectos de un tweet hacen que se difunda más su contenido, lo cual sería útil para que a futuro se pueda maximizar la difusión de un tweet informativo que pueda ayudar alas víctimas del desastre natural. Además queremos saber si hay aspectos que se relacionen con la magnitud del desastre, lo que podría ayudar a predecir y clasificar la magnitud de un desastre a partir de los tweets relacionados a este.

# %% [markdown]
# ### Características del Dataset

# %% [markdown]
# El dataset obtenido del sitio web contiene tres carpetas: **annotations**, **json** y **data_image**.
# La carpeta *annotations* corresponde a archivos *.tsv* con información medida, verificada y etiquetada manualmente acerca de cada tweet.
# En *data_image* se encuentran las rutas a las fotos extraídas de los tweet. Dado que el análisis de imágenes se encuentra fuera del enfoque principal de este primer hito, se decidió no trabajar con esta carpeta. Por último, la carpeta *json* contiene archivos *.json* con información completa y sin filtro de los tweets.
# Este contenido corresponde a un sampleo ya manipulado por los académicos que dejaron disponible el dataset. Por lo que la cantidad de registros de los que se dispone es mucho menor a los registros iniciales descritos en el sitio web.

# %% [markdown]
# ### Exploración de los datos

# %% [markdown]
# Al estudiar el contenido de los archivos *json*, se observó que cada registro de tweet tiene una gran cantidad de información anidada y difícil de analizar con algoritmos convencionales de exploración. Debido a esto, se decidió extraer manualmente las siguientes columnas, las cuales fueron consideradas más útiles para responder a la motivación de este hito:
#
# * *quote_count*: Cantidad de citas a un tweet.
# * *possibly_sensitive*: Booleano, verdadero si el tweet es sensible.
# * *lang*: Idioma del texto.
# * *id*: Identificador único de un tweet.
# * *created_at*: Fecha de creación del tweet.
# * *favorite_count*: Cantidad de favoritos.
# * *text*: Texto del tweet.
# * *reply_count*: Cantidad de respuestas.
# * *entities/hashtags*: Lista de hashtags que tiene el tweet.
# * *entities/urls*: Booleano, verdadero si hay al menos una URL el tweet.
# * *is_quote_status*: Booleano, verdadero si el tweet es una cita,
# * *retweet_count*: Cantidad de retweets.
# * *user/Location*: Localización del usuario que escribió el tweet.
#
# Junto con esto, se decidió descartar los archivos relacionados al desastre de Srilanka, ya que sus registros eran muy reducidos y carecían de dos columnas utilizadas en este estudio.
# Adicionalmente, mediante el análisis del dataframe, se logra apreciar que todas las columnas *lang* del dataframe tenían el valor *en* (inglés), por lo que se terminó descartando el uso del *lang* para el análisis.
#
# En los archivos .tsv de los desastres, los registros tienen las siguientes características de interés:
# * *text_info*: Si el tweet es informativo o no (clasificación binaria)
# * *text_info_conf*: La confiabilidad del aspecto informativo (certeza de la clasificación dada)
# * *text_human*: Qué aspecto humanitario aborda el tweet (8 clases posibles)
# * *text_human_conf*: La confiabilidad del aspecto humanitario (certeza de la clasificación dada)
#
# Estas columnas se extraen del .tsv y se mezclan con las columnas seleccionadas del .json por cada desastre natural, identificando los tweets por su ID. Con esto se construyeron los dataframes utilizados en el estudio de los desastres.
#
# Adicionalmente se agregaron las siguientes columnas:
# * *json_name*: String, corresponde al nombre del desastre al que pertenece el tweet.
# * *has_image*: Booleano, indica si el tweet posee al menos una imagen.
# * *magnitud*: Número, valor correspondiente a la magnitud del desastre natural al que pertenece el tweet.
#
# Existen 13899 registros en total, con el siguiente número de registros por desastre natural:
# * California Wildfires:  1453
# * Hurricane Harvey:  3652
# * Hurricane Irma:  3780
# * Hurricane Maria:  3965
# * Iraq Iran Earthquake:  540
# * Mexico Earthquake:  1167
# * Srilanka Floods:  920
#
# De estos registros, existen 5442 registros informativos y 2188 no informativos, con alta certeza.

# %% [markdown]
# ### Estadísticas y visualizaciones

# %% [markdown]
# #### Estadísticas de resumen

# %% [markdown]
# Se calcularon estadísticas de resumen para todos los desastres, la siguiente tabla muestra las características de resumen para un dataframe que combina los registros de todos los desastres.
# <table>
#   <tr>
#     <th></th>
#     <th>favorite_count</th>
#     <th>retweet_count</th>
#     <th>reply_count</th>
#     <th>quote_count</th>
#     <th>text_info_conf</th>
#     <th>text_human_conf</th>
#   </tr>
#   <tr>
#     <td>count</td>
#     <td>15224.000000</td>
#     <td>15224.000000</td>
#     <td>14911.000000</td>
#     <td>14912.000000</td>
#     <td>13146.000000</td>
#     <td>13146.000000</td>
#   </tr>
#   <tr>
#     <td>mean</td>
#     <td>40.848726</td>
#     <td>21.024961</td>
#     <td>1.591577</td>
#     <td>2.521929</td>
#     <td>0.791305</td>
#     <td>0.791305</td>
#   </tr>
#   <tr>
#     <td>std</td>
#     <td>860.529477</td>
#     <td>472.872880</td>
#     <td>37.779951</td>
#     <td>61.157195</td>
#     <td>0.201238</td>
#     <td>0.201238</td>
#   </tr>
#   <tr>
#     <td>min</td>
#     <td>0.000000</td>
#     <td>0.000000</td>
#     <td>0.000000</td>
#     <td>0.000000</td>
#     <td>0.258100</td>
#     <td>0.258100</td>
#   </tr>
#   <tr>
#     <td>25%</td>
#     <td>0.000000</td>
#     <td>0.000000</td>
#     <td>0.000000</td>
#     <td>0.000000</td>
#     <td>0.659600</td>
#     <td>0.659600</td>
#   </tr>
#   <tr>
#     <td>50%</td>
#     <td>0.000000</td>
#     <td>0.000000</td>
#     <td>0.000000</td>
#     <td>0.000000</td>
#     <td>0.698450</td>
#     <td>0.698450</td>
#   </tr>
#   <tr>
#     <td>75%</td>
#     <td>0.000000</td>
#     <td>0.000000</td>
#     <td>0.000000</td>
#     <td>0.000000</td>
#     <td>1.000000</td>
#     <td>1.000000</td>
#   </tr>
#   <tr>
#     <td>max</td>
#     <td>51726.000000</td>
#     <td>36840.000000</td>
#     <td>3797.000000</td>
#     <td>4010.000000</td>
#     <td>1.000000</td>
#     <td>1.000000</td>
#   </tr>
# </table>
#
# Se puede ver que las interacciones de los tweets son casi inexistentes en la mayoria de registros. Valores distintos a 0 recién empiezan a aparecer por sobre el tercer cuartil de los registros.
# Las estadísticas para cada desastre individual se pueden obtener replicando los códigos del anexo.

# %% [markdown]
# #### Visualizaciones

# %% [markdown]
# ##### Histogramas

# %% [markdown]
# A continuación se muestra un histograma para las columnas *quote_count*, *favorite_count*, *reply_count* y *retweet_count* utilizando el dataframe con los registros de todos los desastres. El eje **y** cuenta la cantidad de tweets y el eje **x** el valor del atributo correspondiente.
#
# <center>
# <div>
#     <img src="images/complete_hist.png" width="400"/>
#     <figcaption>Fig a.1 - Histograma del conjunto completo de desastres</figcaption>
# </div>
# </center>
#
# Al igual que con la tabla anterior, se puede apreciar que casi la totalidad de los tweets tienen una cantidad cercana a 0 de interacciones. Una cantidad mínima de tweets concentran casi todas las interacciones.

# %% [markdown]
# ##### Boxplots

# %% [markdown]
# Se realizaron boxplots para cada dataframe, pero no se pudieron extraer conclusiones significativas sobre el gráfico, además de el hecho de que existen outliers con valores muy altos en los atributos relacionados a las interacciones del tweet. A continuación un ejemplo de boxplots de las columnas *quote_count*, *favorite_count*, *reply_count* y *retweet_count* del dataframe de California Wildfires:
#
# <center>
# <div style="display:flex;">
#     <div>
#     <img src="images/boxplot_1_california.png" style="width:100%;"/>
#     <figcaption>Fig b.1 - California Wildfires</figcaption>
#     </div>
#     <div>
#     <img src="images/boxplot_2_california.png" style="width:100%;"/>
#     <figcaption>Fig b.2 - California Wildfires</figcaption>
#     </div>
# </div>
# </center>

# %% [markdown]
# ##### Conteo de palabras

# %% [markdown]
# Se realizó un conteo de las palabras más comunes en los textos de cada tweet. Se pudo notar que los usuarios tienden mayormente a mencionar el lugar del suceso y el tipo de desastre.
#
# <center>
# <div style="display:flex;">
#     <div>
#     <img src="images/word_count_california.png" style="width:100%;"/>
#     <figcaption>Fig c.1 - California Wildfires</figcaption>
#     </div>
#     <div>
#     <img src="images/word_count_harvey.png" style="width:100%;"/>
#     <figcaption>Fig c.2 - Hurricane Harvey</figcaption>
#     </div>
# </div>
# </center>
# <center>
# <div style="display:flex;">
#     <div>
#     <img src="images/word_count_irma.png" style="width:100%;"/>
#     <figcaption>Fig c.3 - Hurricane Irma</figcaption>
#     </div>
#     <div>
#     <img src="images/word_count_maria.png" style="width:100%;"/>
#     <figcaption>Fig c.4 - Hurricane Maria</figcaption>
#     </div>
# </div>
# </center>
# <center>
# <div style="display:flex;">
#     <div>
#     <img src="images/word_count_iraq.png" style="width:100%;"/>
#     <figcaption>Fig c.5 - Iraq and Iran Earthquake</figcaption>
#     </div>
#     <div>
#     <img src="images/word_count_mexico.png" style="width:100%;"/>
#     <figcaption>Fig c.6 - Mexico Earthquake</figcaption>
#     </div>
# </div>
# </center>

# %% [markdown]
# ##### Correlaciones

# %% [markdown]
# La siguiente tabla muestra las correlaciones entre las columnas cuantitativas del dataframe con todos los desastres. Las columnas *text_info* y *text_human* fueron mapeadas de string a enteros para poder realizar esta correlación.

# %% [markdown]
# <center>
# <table>
#   <tr>
#     <th></th>
#     <th>favorite_count</th>
#     <th>retweet_count</th>
#     <th>possibly_sensitive</th>
#     <th>reply_count</th>
#     <th>quote_count</th>
#     <th>text_info</th>
#     <th>text_human</th>
#   </tr>
#   <tr>
#     <td>favorite_count</td>
#     <td>1.000000</td>
#     <td>0.919928</td>
#     <td>-0.000964</td>
#     <td>0.709378</td>
#     <td>0.553119</td>
#     <td>-0.086793</td>
#     <td>-0.094353</td>
#   </tr>
#   <tr>
#     <td>retweet_count</td>
#     <td>0.919928</td>
#     <td>1.000000</td>
#     <td>-0.001934</td>
#     <td>0.606207</td>
#     <td>0.616322</td>
#     <td>-0.081295</td>
#     <td>-0.088376</td>
#   </tr>
#   <tr>
#     <td>possibly_sensitive</td>
#     <td>-0.000964</td>
#     <td>-0.001934</td>
#     <td>1.000000</td>
#     <td>-0.002455</td>
#     <td>-0.001630</td>
#     <td>0.005151</td>
#     <td>-0.002635</td>
#   </tr>
#   <tr>
#     <td>reply_count</td>
#     <td>0.709378</td>
#     <td>0.606207</td>
#     <td>-0.002455</td>
#     <td>1.000000</td>
#     <td>0.345626</td>
#     <td>-0.077976</td>
#     <td>-0.085081</td>
#   </tr>
#   <tr>
#     <td>quote_count</td>
#     <td>0.553119</td>
#     <td>0.616322</td>
#     <td>-0.001630</td>
#     <td>0.345626</td>
#     <td>1.000000</td>
#     <td>-0.076328</td>
#     <td>-0.083285</td>
#   </tr>
#   <tr>
#     <td>text_info</td>
#     <td>-0.086793</td>
#     <td>-0.081295</td>
#     <td>0.005151</td>
#     <td>-0.077976</td>
#     <td>-0.076328</td>
#     <td>1.000000</td>
#     <td>0.509454</td>
#   </tr>
#   <tr>
#     <td>text_human</td>
#     <td>-0.094353</td>
#     <td>-0.088376</td>
#     <td>-0.002635</td>
#     <td>-0.085081</td>
#     <td>-0.083285</td>
#     <td>0.509454</td>
#     <td>1.000000</td>
#   </tr>
# </table>
# </center>

# %% [markdown]
# Se puede ver la conexión existente entre las interacciones de los usuarios, aquellos tweets con muchos retweets tienden a tener muchas respuestas o ser citados más a menudo. Sin embargo no se aprecia una relación entre estos valores y la clasificación asignada al atributo humanitario o de información de los tweets.
# Se presume que estas últimas columnas dependen mucho más del contenido del texto y las imágenes que se dejaron aparte para este hito. Se evaluará su utilización para las siguientes entregas.

# %% [markdown]
# ##### Clasificación de tweet

# %% [markdown]
# Se realizó un gráfico de barras con el dataframe que contiene todos los registros de desastres para el atributo *text_human*, el cual indica la clasificación del texto del tweet. Los académicos que asignaron estas etiquetas utilizaron un algoritmo que, además de clasificar los tweets, les informaba que tan certera era esta clasificación. Para este gráfico se consideraron todos aquellos tweets que poseen confiabilidad del 100% de su clasificación *text_human*.
#
# <center>
# <div>
#     <img src="images/text_human_conf_graph.png" width="400"/>
#     <figcaption>Fig d.1 - Clasificación humanitaria de tweets</figcaption>
# </div>
# </center>

# %% [markdown]
# ### Mejoras del hito I

# %% [markdown]
# Para iniciar el proceso, se tomó la decisión de trabajar con todos los desastres en conjunto y se agregó una columna que indica a qué desastre pertenece cada tweet. Además, se incluyeron dos nuevas columnas en el conjunto de datos: "TDD", que indica los días transcurridos desde el inicio de la catástrofe, y "has_image", un valor booleano que indica si el tweet contiene una imagen. También se eliminaron todos los tweets que no pertenecieran al año 2017.
#
# A continuación, se realizaron nuevas visualizaciones para mejorar la exploración de datos. El primer gráfico muestra las palabras más frecuentes en los tweets:
#
# <center>
# <div>
#     <img src="images/palabras_frecuentes1.png" width="500"/>
#     <figcaption>Fig d.3 - Gráfico de nube: palabras más frecuentes en los tweets</figcaption>
# </div>
# </center>
#
# <center>
#
#
# <div>
#     <img src="images/palabras_frecuentes2.png" width="860"/>
#     <figcaption>Fig d.4 - Gráfico de barras: palabras más frecuentes en los tweets</figcaption>
# </div>
# </center>
#
# Los siguientes gráficos muestran la cantidad de tweets a lo largo del tiempo y los tweets por cada dias después del desastre:
#
# <center>
# <div>
#     <img src="images/tweets_tiempo.png" width="500"/>
#     <figcaption>Fig d.5 - tweets en el tiempo</figcaption>
# </div>
# </center>
# <center>
# <div>
#     <img src="images/tdd.png" width="500"/>
#     <figcaption>Fig d.6 - Cantidad de tweets por dia luego del desastre</figcaption>
# </div>
# </center>
#
# Durante el análisis, se descubrió que al fusionar los conjuntos de datos del archivo JSON con el archivo TSV, quedaron tweets que no tenían etiquetado. Por lo tanto, se decidió tener un dataframe que contenga únicamente los tweets que están etiquetados según la columna "text_human" (para ciertas visualizaciones) y otro dataframe que incluya todos los tweets mencionados. La cantidad final de tweets quedó de la siguiente manera:
#
# Cantidad de tweets con valores NaN en la columna "text_human":
#
#     Hurricane Irma: 4018 tweets
#     Hurricane Maria: 3995 tweets
#     Hurricane Harvey: 3992 tweets
#     California Wildfires: 1486 tweets
#     Mexico Earthquake: 1237 tweets
#     Sri Lanka Floods: 830 tweets
#     Iraq-Iran Earthquake: 496 tweets
#
# Cantidad de tweets sin valores NaN en la columna "text_human":
#
#     Hurricane Maria: 3537 tweets
#     Hurricane Irma: 3407 tweets
#     Hurricane Harvey: 3315 tweets
#     California Wildfires: 1370 tweets
#     Mexico Earthquake: 1067 tweets
#     Sri Lanka Floods: 751 tweets
#     Iraq-Iran Earthquake: 452 tweets

# %% [markdown]
# ### Preguntas y problemas

# %% [markdown]
# <div class=text-justify>
# Habiendo terminado la exploración del dataset se plantean las siguientes preguntas:
#
# * ¿Existen características en la forma en la que se generan tweets durante una crisis que estén relacionadas con la magnitud del desastre?
# * ¿Podemos determinar el tema de contenido de los tweets en base a las palabras utilizadas en este?
#
# Si hablamos de difusión lo más probable es que la cantidad de seguidores y el número de personas afectadas sea la variable con mayor influencia. Aún así, Se plantea la hipótesis que la retórica que se usa dentro de un tweet es importante y que existen palabras y expresiones que se relacionan positivamente con la difusión.
# </div>

# %% [markdown]
# ### Propuesta experimental

# %% [markdown]
# #### **¿Existen características en la forma en la que se generan tweets durante una crisis que estén relacionadas con la magnitud del desastre?**

# %% [markdown]
# Aqui se trato de responder a la primera pregunta. Como primer paso, es necesario cuantificar la magnitud del desastre. Para lograr esto, calcularemos un indicador que tomará en cuenta la categoría de los tweets, la cual está contenida en el atributo "text human".
#
# El indicador se calcula de la siguiente manera: primero, se filtran los tweets para mantener únicamente aquellos que sean de categoría informativa y relevante. Luego, se cuenta el número de tweets para cada categoría humanitaria y se normaliza en función del número total de tweets. Esto nos proporciona una medida del impacto del desastre en cada aspecto humanitario.
#
# A continuación, se ponderan estas categorías utilizando sus respectivos pesos:
#
# * "Affected individuals": 0.2
# * "Infrastructure and utility damage": 0.2
# * "Injured or dead people": 0.3
# * "Missing or found people": 0.05
# * "Not humanitarian": 0
# * "Rescue, volunteering or donation effort": 0.05
# * "Vehicle damage": 0.05
# * "Other relevant information": 0.15
#
# Estos valores ponderados se suman, lo que resulta en el indicador de magnitud del desastre. Este valor puede interpretarse como una estimación de la proporción de tweets informativos y relevantes que reflejan el impacto del desastre en diferentes aspectos humanitarios.

# %% [markdown]
# Esta magnitud se agregó al dataframe en una columna llamada "magnitud" igual a todos los tweets de un mismo desastre.
# Cabe destacar que se eliminaron los registros del desastre de Sri Lanka y aquellos registros que eran NaN.
#
# Luego de agregar la columna _magnitud_ al dataframe, se aplicó clustering sobre los registros. Para ello, primeramente, se conservaron las siguientes columnas:
#
#    * favorite_count
#    * retweet_count
#    * reply_count
#    * quote_count
#    * tdd
#    * magnitud
#
# Tras esto, se preprocesaron los registros usando la librería scikit-learn y se utilizó el método del codo para encontrar los números de clusters óptimos usando **K-Means** como método de clustering. El resultado fue 3 clusters como número óptimo.
#
# <center>
# <div>
#     <img src="images/codo.png" width="400"/>
#     <figcaption>Fig d.7 - Gráfico del metodo del codo</figcaption>
# </div>
# </center>
#
# Luego, se aplicó el algoritmo _K-Means_ nuevamente con 3 clusters. A continuación se muestra el gráfico resultante después de reducir la dimensionalidad utilizando PCA y los centroides obtenidos:
#
# <center>
# <div>
#     <img src="images/kmeans.png" width="400"/>
#     <figcaption>Fig d.8 - Gráfico de los clusters</figcaption>
# </div>
# </center>

# %% [markdown]
# <center>
# <table>
#   <tr>
#     <th>favorite_count</th>
#     <th>retweet_count</th>
#     <th>reply_count</th>
#     <th>quote_count</th>
#     <th>tdd</th>
#     <th>magnitud</th>
#   </tr>
#   <tr>
#     <td>15.944902</td>
#     <td>8.721068</td>
#     <td>0.915700</td>
#     <td>1.413947</td>
#     <td>12.572835</td>
#     <td>0.060678</td>
#   </tr>
#   <tr>
#     <td>45792.666667</td>
#     <td>22862.333333</td>
#     <td>1807.000000</td>
#     <td>1157.666667</td>
#     <td>4.666667</td>
#     <td>0.055333</td>
#   </tr>
#   <tr>
#     <td>15875.363636</td>
#     <td>6813.272727</td>
#     <td>360.909091</td>
#     <td>1082.363636</td>
#     <td>3.545455</td>
#     <td>0.058727</td>
#   </tr>
# </table>
#
# </center>

# %% [markdown]
# Basándonos en los grupos obtenidos, podemos inferir lo siguiente:
#
#     Grupo 1: Este grupo está compuesto por tweets que parecen no tener mucha relevancia o interacciones significativas. Estos tweets suelen ser más antiguos o estar más alejados en el tiempo del desastre.
#
#     Grupo 2: En este grupo se encuentran los tweets que han sido altamente virales, con una gran cantidad de interacciones. Estos tweets suelen tener fechas cercanas al desastre y han generado un mayor impacto en las redes sociales.
#
#     Grupo 3: Los tweets en este grupo muestran ciertas interacciones, pero no alcanzan el nivel de viralidad del Grupo 2. También se caracterizan por tener fechas cercanas al desastre.
#
# Además, se calculó el Silhouette Score y se obtuvo un valor de 0.996, lo cual indica que los clusters están bien definidos y separados entre sí.
#
# Como conclusiones preliminares, se puede deducir que las características de un tweet no tienen una relación aparente con la magnitud del desastre. Aunque se observan diferencias en la viralidad y la cercanía temporal al desastre, los grupos de clustering no muestran una magnitud claramente relacionada con estas características. Para el próximo hito, se plantea la posibilidad de calcular la magnitud del desastre utilizando datos externos y aplicar la misma metodología descrita para obtener una evaluación más precisa

# %% [markdown]
# #### **¿Podemos determinar el tema de contenido de los tweets en base a las palabras utilizadas en este?**

# %% [markdown]
# Para responder a esta pregunta, se requiere realizar un análisis del texto de los tweets utilizando técnicas de procesamiento de lenguaje natural (NLP).
#
# Inicialmente, se planteó la utilización de la técnica Word2Vec para realizar el embedding del texto de los tweets. Sin embargo, después de observar algunos resultados preliminares, se decidió cambiar a la utilización del modelo GloVe, el cual cuenta con vectores preprocesados de dimensión 200. Esto mejorará los resultados y la velocidad de procesamiento. Además, se utilizarán las palabras más frecuentes del dataset, en este caso, los nombres de los desastres y sus ubicaciones, como stopwords durante el preprocesamiento para el entrenamiento del clasificador.
#
# A continuación, se separarán los conjuntos de entrenamiento y prueba en un 80\% y 20\% de los datos, respectivamente. Posteriormente, se generarán los vectores y los textos de entrenamiento y prueba. Finalmente, se calculará el promedio de la representación vectorial de cada palabra en un tweet.
#
# Con todo este procesamiento, se utilizarán diferentes clasificadores y se compararán sus resultados. En particular, se planea utilizar los siguientes:
#
# - LinearSVC
# - DecisionTreeClassifier
# - RandomForestClassifier
# - NaiveBayes
#
# Además, se considerará realizar un rebalanceo de las clases, ya que las últimas 4 etiquetas del gráfico presentan una frecuencia considerablemente menor que las demás. Se propone agrupar estas 4 etiquetas en una única columna para mitigar este desequilibrio. También se evaluarán qué parámetros utilizar para entrenar el clasificador, además del texto.
#
# Para evaluar la efectividad de los clasificadores, se utilizarán diversas métricas como la exactitud (accuracy), la precisión (precision), la recuperación (recall) y la puntuación F1 (F1 score).

# %% [markdown]
# ## Aportes
# Para este informe se realizaron las siguientes contribuciones.
#
# * Redaccion metodologia pregunta 1: Jessica
# * Redacción Metodologia pregunta 2: Stevens y Agustín
# * Redacción Mejoras hito I: Agustín
# * Imagenes: Jesús y Stevens
# * Códigos de mejora: Jorge y Agustín
# * Presentación: Jorge, Jesús y Jessica

# %% [markdown]
# ## Anexo
# Los códigos se encuentran en la carpeta "/codigo". Por ejemplo, el archivo visualizaciones_california.ipynb contiene el código completo para generar las estadísticas y visualizaciones que son replicables para cada dataframe. Además de los códigos individuales para los 6 desastres, se añade el código utilizado con el dataset que tiene todos los datos.
