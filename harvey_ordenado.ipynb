# %% [markdown]
# # Análisis de los datos relacionado al Huracán Harvey
# Se comienza con los imports

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import regex as re
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\steve\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Se definen funciones necesarias para extraer los datos del archivo .json y .tsv

# %%
def get_hashtags_text(x):
    if pd.notna(x) and 'hashtags' in x and x['hashtags']:
        hashtags = x['hashtags']
        hashtags_text = [ht['text'] for ht in hashtags]
        return hashtags_text
    else:
        return None

def get_urls(x):
    if pd.notna(x) and 'urls' in x and x['urls']:
        return True
    return False


def get_user_location(x):
    if pd.notna(x) and 'location' in x:
        return x['location']
    else:
        return None


  
def load_json_old(file_path):
    """
    Carga un archivo JSON en un DataFrame de Pandas.

    Args:
        file_path (str): Ruta del archivo JSON.

    Returns:
        pandas.DataFrame: DataFrame con los datos del archivo JSON.
    """
    # Crear un nuevo DataFrame vacío
    df_new = pd.DataFrame()

    try:
        # Leer el archivo JSON línea por línea y cargar los datos en una lista
        datos_json = []
        with open(file_path, "r", encoding="utf-8") as f:
            for line in f:
                data = json.loads(line)
                datos_json.append(data)

        # Convertir la lista de datos en un DataFrame de Pandas
        df = pd.DataFrame(datos_json)

        # Actualizar las columnas del nuevo DataFrame con los datos válidos
        df_new['id'] = df['id']
        df_new['lang'] = df['lang']
        df_new['text'] = df['text']
        df_new['favorite_count'] = df['favorite_count']
        df_new['retweet_count'] = df['retweet_count']
        df_new['possibly_sensitive'] = df['possibly_sensitive']
        df_new['created_at'] = df['created_at']
        df_new['is_quote_status'] = df['is_quote_status']
        df_new = df_new[df['retweeted_status'].isna()]
        df_new['entities_hashtags_text'] = df['entities'].apply(get_hashtags_text)
        df_new['entities_urls'] = df['entities'].apply(get_urls)
        df_new['user_location'] = df['user'].apply(get_user_location)

        # Manejar la excepción de KeyError para las columnas opcionales
        try:
            df_new['reply_count'] = df['reply_count']
            df_new['quote_count'] = df['quote_count']
        except KeyError as e:
            print(f'Una o más columnas no existen en el archivo JSON: {e}')

        # Eliminar las columnas "user" y "entities"
        #df_new.drop(['user', 'entities'], axis=1, inplace=True)

    except Exception as e:
        print(f'Se produjo una excepción: {e}')

    # Retornar el DataFrame resultante
    return df_new

def load_json2(file_path):
    """
    Carga un archivo JSON en un DataFrame de Pandas.

    Args:
        file_path (str): Ruta del archivo JSON.

    Returns:
        pandas.DataFrame: DataFrame con los datos del archivo JSON.
    """
    # Leer el archivo JSON línea por línea y cargar los datos en una lista
    datos_json = []
    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            data = json.loads(line)
            if 'retweeted_status' in data and data['retweeted_status'] != None:
                data = data['retweeted_status']
            datos_json.append(data)

    # Convertir la lista de datos en un DataFrame de Pandas
    df = pd.DataFrame(datos_json)

    # Crear un nuevo DataFrame con las columnas deseadas
    df_new = df[['id','lang','text','favorite_count','quote_count','reply_count','retweet_count', 'possibly_sensitive','created_at',
                    'entities', 'is_quote_status',
                'user']]


    # Filtrar las filas donde "retweeted_status" no sea None o NaN
    #df_new = df_new[df['retweeted_status'].isna()]

    # Extraer la información de los hashtags, URLs y ubicación de usuario y agregarla como nuevas columnas
    df_new['entities_hashtags_text'] = df_new['entities'].apply(get_hashtags_text).apply(lambda x: x if x else None)
    df_new['entities_urls'] = df_new['entities'].apply(get_urls)
    df_new['user_location'] = df_new['user'].apply(get_user_location)

    # Eliminar las columnas "user" y "entities"
    df_new.drop(['user', 'entities'], axis=1, inplace=True)

    # Retornar el DataFrame resultante
    return df_new

def load_json(file_path):
  
    df_new = pd.DataFrame()

    try:
        # Leer el archivo JSON línea por línea y cargar los datos en una lista
        datos_json = []
        with open(file_path, "r", encoding="utf-8") as f:
            for line in f:
                data = json.loads(line)
                if 'retweeted_status' in data and data['retweeted_status'] != None:
                    data = data['retweeted_status']
                datos_json.append(data)

      
        df = pd.DataFrame(datos_json)

        df_new['id'] = df['id']
        df_new['lang'] = df['lang']
        df_new['text'] = df['text']
        df_new['favorite_count'] = df['favorite_count']
        df_new['retweet_count'] = df['retweet_count']
        df_new['possibly_sensitive'] = df['possibly_sensitive']
        df_new['created_at'] = df['created_at']
        df_new['is_quote_status'] = df['is_quote_status']
        df_new['entities_hashtags_text'] = df['entities'].apply(get_hashtags_text)
        df_new['entities_urls'] = df['entities'].apply(get_urls)
        df_new['user_location'] = df['user'].apply(get_user_location)
        try:
            df_new['reply_count'] = df['reply_count']
            df_new['quote_count'] = df['quote_count']
        except KeyError as e:
            print(f'Una o más columnas no existen en el archivo JSON: {e}')
    except Exception as e:
        print(f'Se produjo una excepción: {e}')

    # Retornar el DataFrame resultante
    return df_new

# %% [markdown]
# Se crea la dataframe sobre el Irma

# %%
irma_json = load_json("RDATA/CrisisMMD_v2.0/json/hurricane_harvey_final_data.json")
irma_tsv = pd.read_table("RDATA/CrisisMMD_v2.0/annotations/hurricane_harvey_final_data.tsv")

irma = pd.merge(irma_json, irma_tsv[['tweet_id', 'text_info', 'text_info_conf', 'text_human', 'text_human_conf']],
                    left_on='id', right_on='tweet_id', how='left')
irma.drop('tweet_id',axis=1,inplace=True)
irma.T
# Out:
#                                                                      0
# id                                                     901548512709574657  \
# lang                                                                   en
# text                    #ajwamood : Harvey the first major hurricane t...
# favorite_count                                                          0
# retweet_count                                                           1
# possibly_sensitive                                                  False
# created_at                                 Sat Aug 26 20:54:50 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                     [ajwamood, US]
# entities_urls                                                       False
# user_location                                                   Ajman,UAE
# reply_count                                                           NaN
# quote_count                                                           NaN
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                      1
# id                                                     901604877029257216  \
# lang                                                                   en
# text                    When we get back to SCHS after Harvey hits : h...
# favorite_count                                                         14
# retweet_count                                                           9
# possibly_sensitive                                                  False
# created_at                                 Sun Aug 27 00:38:48 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                       False
# user_location                                                Pearland, TX
# reply_count                                                           NaN
# quote_count                                                           NaN
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                      2
# id                                                     901646127895863296  \
# lang                                                                   en
# text                    Not always good when your city shows up on a s...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sun Aug 27 03:22:43 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                   [HurricaneHarvey, ItAintOverYet]
# entities_urls                                                       False
# user_location                                                  Texas, USA
# reply_count                                                           NaN
# quote_count                                                           NaN
# text_info                                                     informative
# text_info_conf                                                     0.9167
# text_human                                     other_relevant_information
# text_human_conf                                                    0.9167
#
#                                                                      3
# id                                                     901194985885777920  \
# lang                                                                   en
# text                    Side by side satellite images compare the size...
# favorite_count                                                      30970
# retweet_count                                                       25263
# possibly_sensitive                                                  False
# created_at                                 Fri Aug 25 21:30:02 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                       False
# user_location                                                        None
# reply_count                                                           NaN
# quote_count                                                           NaN
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                      4
# id                                                     901644108023832576  \
# lang                                                                   en
# text                    Let Steve Harvey nowhere near the judges score...
# favorite_count                                                         23
# retweet_count                                                          11
# possibly_sensitive                                                  False
# created_at                                 Sun Aug 27 03:14:41 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                              [MayweathervMcgregor]
# entities_urls                                                       False
# user_location                                 Vancouver, British Columbia
# reply_count                                                           NaN
# quote_count                                                           NaN
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                      5
# id                                                     901158123825754113  \
# lang                                                                   en
# text                    We Survived Once We Can Survive Again #Hurrica...
# favorite_count                                                       9042
# retweet_count                                                        4404
# possibly_sensitive                                                  False
# created_at                                 Fri Aug 25 19:03:34 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                  [HurricaneHarvey]
# entities_urls                                                       False
# user_location                                                  Saytown,TX
# reply_count                                                           NaN
# quote_count                                                           NaN
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                      6
# id                                                     901645886400421888  \
# lang                                                                   en
# text                    My street in SE #Houston is now a river. That ...
# favorite_count                                                          0
# retweet_count                                                           1
# possibly_sensitive                                                  False
# created_at                                 Sun Aug 27 03:21:45 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                  [Houston, Harvey]
# entities_urls                                                       False
# user_location                                                        None
# reply_count                                                           NaN
# quote_count                                                           NaN
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                      7
# id                                                     901646377620578304  \
# lang                                                                   en
# text                    Texas county's long recovery from Hurricane Ha...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sun Aug 27 03:23:42 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                        None
# reply_count                                                           NaN
# quote_count                                                           NaN
# text_info                                                     informative
# text_info_conf                                                     0.7999
# text_human                                     other_relevant_information
# text_human_conf                                                    0.7999
#
#                                                                      8
# id                                                     901646404040437760  \
# lang                                                                   en
# text                    hypervocal: Help Hurricane Harvey Victims in T...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sun Aug 27 03:23:49 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                             Boston, England
# reply_count                                                           NaN
# quote_count                                                           NaN
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                         rescue_volunteering_or_donation_effort
# text_human_conf                                                       1.0
#
#                                                                      9
# id                                                     901558001261268992  \
# lang                                                                   en
# text                    @abc13houston Tornado forming on Barker Cypres...
# favorite_count                                                         63
# retweet_count                                                          44
# possibly_sensitive                                                  False
# created_at                                 Sat Aug 26 21:32:32 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                       False
# user_location                                                  Texas, USA
# reply_count                                                           NaN
# quote_count                                                           NaN
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                         ...
# id                      ...  \
# lang                    ...
# text                    ...
# favorite_count          ...
# retweet_count           ...
# possibly_sensitive      ...
# created_at              ...
# is_quote_status         ...
# entities_hashtags_text  ...
# entities_urls           ...
# user_location           ...
# reply_count             ...
# quote_count             ...
# text_info               ...
# text_info_conf          ...
# text_human              ...
# text_human_conf         ...
#
#                                                                      4316
# id                                                     903115028982751232  \
# lang                                                                   en
# text                    All wet.\n\n#resist #Harvey #presidential http...
# favorite_count                                                        239
# retweet_count                                                         105
# possibly_sensitive                                                  False
# created_at                                 Thu Aug 31 04:39:36 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                     [resist, Harvey, presidential]
# entities_urls                                                       False
# user_location                                                Vancouver BC
# reply_count                                                           1.0
# quote_count                                                           7.0
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                      4317
# id                                                     910261798569472003  \
# lang                                                                   en
# text                    Hurricane Harvey's Latest Victim: @HoustonBall...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Sep 19 21:58:19 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                        None
# reply_count                                                           0.0
# quote_count                                                           0.0
# text_info                                                     informative
# text_info_conf                                                     0.6333
# text_human                                     other_relevant_information
# text_human_conf                                                    0.6333
#
#                                                                      4318
# id                                                     910262990540242944  \
# lang                                                                   en
# text                    Houston was built for cars. What happens when ...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Sep 19 22:03:03 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                           [Harvey]
# entities_urls                                                        True
# user_location                                                 Seattle, WA
# reply_count                                                           0.0
# quote_count                                                           0.0
# text_info                                                     informative
# text_info_conf                                                     0.6746
# text_human                                                 vehicle_damage
# text_human_conf                                                    0.6746
#
#                                                                      4319
# id                                                     910263603533664261  \
# lang                                                                   en
# text                    We delivered our relief efforts to Rockport to...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Sep 19 22:05:29 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                             [Tackleberrys, harvey]
# entities_urls                                                       False
# user_location                                              San Marcos, TX
# reply_count                                                           0.0
# quote_count                                                           0.0
# text_info                                                     informative
# text_info_conf                                                     0.6519
# text_human                         rescue_volunteering_or_donation_effort
# text_human_conf                                                    0.6519
#
#                                                                      4320
# id                                                     910263603533664261  \
# lang                                                                   en
# text                    We delivered our relief efforts to Rockport to...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Sep 19 22:05:29 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                             [Tackleberrys, harvey]
# entities_urls                                                       False
# user_location                                              San Marcos, TX
# reply_count                                                           0.0
# quote_count                                                           0.0
# text_info                                                     informative
# text_info_conf                                                     0.6519
# text_human                         rescue_volunteering_or_donation_effort
# text_human_conf                                                    0.6519
#
#                                                                      4321
# id                                                     910263603533664261  \
# lang                                                                   en
# text                    We delivered our relief efforts to Rockport to...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Sep 19 22:05:29 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                             [Tackleberrys, harvey]
# entities_urls                                                       False
# user_location                                              San Marcos, TX
# reply_count                                                           0.0
# quote_count                                                           0.0
# text_info                                                     informative
# text_info_conf                                                     0.6519
# text_human                         rescue_volunteering_or_donation_effort
# text_human_conf                                                    0.6519
#
#                                                                      4322
# id                                                     910263603533664261  \
# lang                                                                   en
# text                    We delivered our relief efforts to Rockport to...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Sep 19 22:05:29 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                             [Tackleberrys, harvey]
# entities_urls                                                       False
# user_location                                              San Marcos, TX
# reply_count                                                           0.0
# quote_count                                                           0.0
# text_info                                                     informative
# text_info_conf                                                     0.6519
# text_human                         rescue_volunteering_or_donation_effort
# text_human_conf                                                    0.6519
#
#                                                                      4323
# id                                                     910265204990029824  \
# lang                                                                   en
# text                    Get your parts from the best in the industry, ...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Sep 19 22:11:51 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                           Las Vegas, Nevada
# reply_count                                                           0.0
# quote_count                                                           0.0
# text_info                                                 not_informative
# text_info_conf                                                     0.8131
# text_human                                               not_humanitarian
# text_human_conf                                                    0.8131
#
#                                                                      4324
# id                                                     910268744697397248  \
# lang                                                                   en
# text                    3 hats for #HurricaneHarvey fundraiser.  So pr...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Sep 19 22:25:55 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                         [HurricaneHarvey, pugchat]
# entities_urls                                                       False
# user_location                                               Fullerton, CA
# reply_count                                                           0.0
# quote_count                                                           0.0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                         rescue_volunteering_or_donation_effort
# text_human_conf                                                       1.0
#
#                                                                      4325
# id                                                     910269781588299776
# lang                                                                   en
# text                    .@UWMadison students in Houston to aid post-Ha...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Sep 19 22:30:02 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                               Madison, Wis.
# reply_count                                                           0.0
# quote_count                                                           0.0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                         rescue_volunteering_or_donation_effort
# text_human_conf                                                       1.0
#
# [17 rows x 4326 columns]

# %% [markdown]
# Se revisa su tamaño y que cotiene

# %%
irma.shape
# Out:
# (4326, 17)

# %%
summary = irma.describe()
print(summary)
# Out:
#                  id  favorite_count  retweet_count  reply_count  quote_count
# count  4.326000e+03     4326.000000    4326.000000  3992.000000  3992.000000  \
# mean   9.054143e+17       54.874942      25.815072     1.995741     1.751002
# std    1.056207e+16     1156.525957     557.710595    62.046193    27.753020
# min    4.855547e+17        0.000000       0.000000     0.000000     0.000000
# 25%    9.046973e+17        0.000000       0.000000     0.000000     0.000000
# 50%    9.058530e+17        0.000000       0.000000     0.000000     0.000000
# 75%    9.075807e+17        0.000000       0.000000     0.000000     0.000000
# max    9.102698e+17    43273.000000   25263.000000  3797.000000  1026.000000
#
#        text_info_conf  text_human_conf
# count     3648.000000      3648.000000
# mean         0.776507         0.776507
# std          0.204395         0.204395
# min          0.258100         0.258100
# 25%          0.655700         0.655700
# 50%          0.696300         0.696300
# 75%          1.000000         1.000000
# max          1.000000         1.000000

# %%
# select only numerical columns
numerical_columns = irma.select_dtypes(include=['int64', 'float64']).columns.tolist()

# select only non-numerical columns
categorical_columns = irma.select_dtypes(include=['object']).columns.tolist()

boolean_columns = irma.select_dtypes(include=['bool']).columns.tolist()

print(numerical_columns)

print(categorical_columns)

print(boolean_columns)
# Out:
# ['id', 'favorite_count', 'retweet_count', 'reply_count', 'quote_count', 'text_info_conf', 'text_human_conf']
# ['lang', 'text', 'created_at', 'entities_hashtags_text', 'user_location', 'text_info', 'text_human']
# ['possibly_sensitive', 'is_quote_status', 'entities_urls']

# %% [markdown]
# Se revisa si hay ids duplicadas, y si existen, eliminar esas filas del dataframe

# %%
irma["id"].value_counts()
# Out:
# id
# 905745260927750144    4
# 901743093493489664    4
# 907974968549498880    4
# 906196156262338560    4
# 907069889843748864    4
#                      ..
# 905169468971778048    1
# 905169543877812224    1
# 905169671179165696    1
# 905120944242532353    1
# 910269781588299776    1
# Name: count, Length: 3992, dtype: int64

# %%
irma = irma.drop_duplicates(subset=['id']).reset_index(drop=True)
irma
# Out:
#                       id lang
# 0     901548512709574657   en  \
# 1     901604877029257216   en
# 2     901646127895863296   en
# 3     901194985885777920   en
# 4     901644108023832576   en
# ...                  ...  ...
# 3987  910262990540242944   en
# 3988  910263603533664261   en
# 3989  910265204990029824   en
# 3990  910268744697397248   en
# 3991  910269781588299776   en
#
#                                                    text  favorite_count
# 0     #ajwamood : Harvey the first major hurricane t...               0  \
# 1     When we get back to SCHS after Harvey hits : h...              14
# 2     Not always good when your city shows up on a s...               0
# 3     Side by side satellite images compare the size...           30970
# 4     Let Steve Harvey nowhere near the judges score...              23
# ...                                                 ...             ...
# 3987  Houston was built for cars. What happens when ...               0
# 3988  We delivered our relief efforts to Rockport to...               0
# 3989  Get your parts from the best in the industry, ...               0
# 3990  3 hats for #HurricaneHarvey fundraiser.  So pr...               0
# 3991  .@UWMadison students in Houston to aid post-Ha...               0
#
#       retweet_count  possibly_sensitive                      created_at
# 0                 1               False  Sat Aug 26 20:54:50 +0000 2017  \
# 1                 9               False  Sun Aug 27 00:38:48 +0000 2017
# 2                 0               False  Sun Aug 27 03:22:43 +0000 2017
# 3             25263               False  Fri Aug 25 21:30:02 +0000 2017
# 4                11               False  Sun Aug 27 03:14:41 +0000 2017
# ...             ...                 ...                             ...
# 3987              0               False  Tue Sep 19 22:03:03 +0000 2017
# 3988              0               False  Tue Sep 19 22:05:29 +0000 2017
# 3989              0               False  Tue Sep 19 22:11:51 +0000 2017
# 3990              0               False  Tue Sep 19 22:25:55 +0000 2017
# 3991              0               False  Tue Sep 19 22:30:02 +0000 2017
#
#       is_quote_status            entities_hashtags_text  entities_urls
# 0               False                    [ajwamood, US]          False  \
# 1               False                              None          False
# 2               False  [HurricaneHarvey, ItAintOverYet]          False
# 3               False                              None          False
# 4               False             [MayweathervMcgregor]          False
# ...               ...                               ...            ...
# 3987            False                          [Harvey]           True
# 3988            False            [Tackleberrys, harvey]          False
# 3989            False                              None           True
# 3990            False        [HurricaneHarvey, pugchat]          False
# 3991            False                              None           True
#
#                     user_location  reply_count  quote_count        text_info
# 0                       Ajman,UAE          NaN          NaN              NaN  \
# 1                    Pearland, TX          NaN          NaN              NaN
# 2                      Texas, USA          NaN          NaN      informative
# 3                            None          NaN          NaN              NaN
# 4     Vancouver, British Columbia          NaN          NaN              NaN
# ...                           ...          ...          ...              ...
# 3987                  Seattle, WA          0.0          0.0      informative
# 3988               San Marcos, TX          0.0          0.0      informative
# 3989            Las Vegas, Nevada          0.0          0.0  not_informative
# 3990                Fullerton, CA          0.0          0.0      informative
# 3991                Madison, Wis.          0.0          0.0      informative
#
#       text_info_conf                              text_human  text_human_conf
# 0                NaN                                     NaN              NaN
# 1                NaN                                     NaN              NaN
# 2             0.9167              other_relevant_information           0.9167
# 3                NaN                                     NaN              NaN
# 4                NaN                                     NaN              NaN
# ...              ...                                     ...              ...
# 3987          0.6746                          vehicle_damage           0.6746
# 3988          0.6519  rescue_volunteering_or_donation_effort           0.6519
# 3989          0.8131                        not_humanitarian           0.8131
# 3990          1.0000  rescue_volunteering_or_donation_effort           1.0000
# 3991          1.0000  rescue_volunteering_or_donation_effort           1.0000
#
# [3992 rows x 17 columns]

# %% [markdown]
# Con los datos no duplicados, se revisa la variedad de ciertas columnas. Si estás columnas solo retornan un único valor, se eliminan por redundancia.

# %%
language = irma["lang"]

wa = []

for i in language:
    if i not in wa:
        wa.append(i)

print(wa)
# Out:
# ['en']

# %%
favorite = irma["favorite_count"]
RT = irma["retweet_count"]

i = 0

no_fav = []
no_RT = []

while i < len(favorite):
    if favorite[i]== 0:
        no_fav.append("NO")
    if RT[i] == 0:
        no_RT.append("NO")


    i +=1

print(len(favorite))
print(len(no_fav))
print(len(RT))
print(len(no_RT))
# Out:
# 3992
# 3460
# 3992
# 3314

# %%
reply = irma["reply_count"]
quotes = irma["quote_count"]

i=0

no_reply = []
no_quote = []

while i<len(reply):
    if reply[i] == 0:
        no_reply.append("NO")
    if quotes[i] == 0 :
        no_quote.append("NO")
    i += 1

print(len(reply))
print(len(no_reply))
print(len(quotes))
print(len(no_quote))
# Out:
# 3992
# 3461
# 3992
# 3466

# %%
is_quote = irma["is_quote_status"]

is_not_quote = []

i = 0
while i<len(is_quote):
    if not is_quote[i]:
        is_not_quote.append("AAA")
    i+=1

print(len(is_quote))
print(len(is_not_quote))
# Out:
# 3992
# 3980

# %%
is_sensitive = irma["possibly_sensitive"]

is_not_sensitive= []

i = 0
while i<len(is_sensitive):
    if not is_sensitive[i]:
        is_not_sensitive.append("AAA")
    i+=1

print(len(is_sensitive))
print(len(is_not_sensitive))
# Out:
# 3992
# 3964

# %% [markdown]
# Se descubre que todos los tweets son en inglés, por lo que se elimina la columna "lang". El resto de los datos presenta algo de variedad, por lo que se mantienen.

# %%
new_irma = irma.drop(["lang"], axis=1)
new_irma.T
# Out:
#                                                                      0
# id                                                     901548512709574657  \
# text                    #ajwamood : Harvey the first major hurricane t...
# favorite_count                                                          0
# retweet_count                                                           1
# possibly_sensitive                                                  False
# created_at                                 Sat Aug 26 20:54:50 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                     [ajwamood, US]
# entities_urls                                                       False
# user_location                                                   Ajman,UAE
# reply_count                                                           NaN
# quote_count                                                           NaN
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                      1
# id                                                     901604877029257216  \
# text                    When we get back to SCHS after Harvey hits : h...
# favorite_count                                                         14
# retweet_count                                                           9
# possibly_sensitive                                                  False
# created_at                                 Sun Aug 27 00:38:48 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                       False
# user_location                                                Pearland, TX
# reply_count                                                           NaN
# quote_count                                                           NaN
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                      2
# id                                                     901646127895863296  \
# text                    Not always good when your city shows up on a s...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sun Aug 27 03:22:43 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                   [HurricaneHarvey, ItAintOverYet]
# entities_urls                                                       False
# user_location                                                  Texas, USA
# reply_count                                                           NaN
# quote_count                                                           NaN
# text_info                                                     informative
# text_info_conf                                                     0.9167
# text_human                                     other_relevant_information
# text_human_conf                                                    0.9167
#
#                                                                      3
# id                                                     901194985885777920  \
# text                    Side by side satellite images compare the size...
# favorite_count                                                      30970
# retweet_count                                                       25263
# possibly_sensitive                                                  False
# created_at                                 Fri Aug 25 21:30:02 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                       False
# user_location                                                        None
# reply_count                                                           NaN
# quote_count                                                           NaN
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                      4
# id                                                     901644108023832576  \
# text                    Let Steve Harvey nowhere near the judges score...
# favorite_count                                                         23
# retweet_count                                                          11
# possibly_sensitive                                                  False
# created_at                                 Sun Aug 27 03:14:41 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                              [MayweathervMcgregor]
# entities_urls                                                       False
# user_location                                 Vancouver, British Columbia
# reply_count                                                           NaN
# quote_count                                                           NaN
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                      5
# id                                                     901158123825754113  \
# text                    We Survived Once We Can Survive Again #Hurrica...
# favorite_count                                                       9042
# retweet_count                                                        4404
# possibly_sensitive                                                  False
# created_at                                 Fri Aug 25 19:03:34 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                  [HurricaneHarvey]
# entities_urls                                                       False
# user_location                                                  Saytown,TX
# reply_count                                                           NaN
# quote_count                                                           NaN
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                      6
# id                                                     901645886400421888  \
# text                    My street in SE #Houston is now a river. That ...
# favorite_count                                                          0
# retweet_count                                                           1
# possibly_sensitive                                                  False
# created_at                                 Sun Aug 27 03:21:45 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                  [Houston, Harvey]
# entities_urls                                                       False
# user_location                                                        None
# reply_count                                                           NaN
# quote_count                                                           NaN
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                      7
# id                                                     901646377620578304  \
# text                    Texas county's long recovery from Hurricane Ha...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sun Aug 27 03:23:42 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                        None
# reply_count                                                           NaN
# quote_count                                                           NaN
# text_info                                                     informative
# text_info_conf                                                     0.7999
# text_human                                     other_relevant_information
# text_human_conf                                                    0.7999
#
#                                                                      8
# id                                                     901646404040437760  \
# text                    hypervocal: Help Hurricane Harvey Victims in T...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sun Aug 27 03:23:49 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                             Boston, England
# reply_count                                                           NaN
# quote_count                                                           NaN
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                         rescue_volunteering_or_donation_effort
# text_human_conf                                                       1.0
#
#                                                                      9
# id                                                     901558001261268992  \
# text                    @abc13houston Tornado forming on Barker Cypres...
# favorite_count                                                         63
# retweet_count                                                          44
# possibly_sensitive                                                  False
# created_at                                 Sat Aug 26 21:32:32 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                       False
# user_location                                                  Texas, USA
# reply_count                                                           NaN
# quote_count                                                           NaN
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                         ...
# id                      ...  \
# text                    ...
# favorite_count          ...
# retweet_count           ...
# possibly_sensitive      ...
# created_at              ...
# is_quote_status         ...
# entities_hashtags_text  ...
# entities_urls           ...
# user_location           ...
# reply_count             ...
# quote_count             ...
# text_info               ...
# text_info_conf          ...
# text_human              ...
# text_human_conf         ...
#
#                                                                      3982
# id                                                     910247262135218176  \
# text                    Harvey James was born on this day https://t.co...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Sep 19 21:00:33 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                           Sydney, Australia
# reply_count                                                           0.0
# quote_count                                                           0.0
# text_info                                                 not_informative
# text_info_conf                                                        1.0
# text_human                                               not_humanitarian
# text_human_conf                                                       1.0
#
#                                                                      3983
# id                                                     910254709289684992  \
# text                    What Harvey Can Teach Us About Resilient Trans...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Sep 19 21:30:09 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                New York, NY
# reply_count                                                           0.0
# quote_count                                                           0.0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                                     other_relevant_information
# text_human_conf                                                       1.0
#
#                                                                      3984
# id                                                     910257037140996102  \
# text                    Houston Office Market Sees Slight Increase in ...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Sep 19 21:39:24 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                              [CRE]
# entities_urls                                                        True
# user_location                                              Doylestown, PA
# reply_count                                                           0.0
# quote_count                                                           0.0
# text_info                                                     informative
# text_info_conf                                                     0.6691
# text_human                                     other_relevant_information
# text_human_conf                                                    0.6691
#
#                                                                      3985
# id                                                     903115028982751232  \
# text                    All wet.\n\n#resist #Harvey #presidential http...
# favorite_count                                                        239
# retweet_count                                                         105
# possibly_sensitive                                                  False
# created_at                                 Thu Aug 31 04:39:36 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                     [resist, Harvey, presidential]
# entities_urls                                                       False
# user_location                                                Vancouver BC
# reply_count                                                           1.0
# quote_count                                                           7.0
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                      3986
# id                                                     910261798569472003  \
# text                    Hurricane Harvey's Latest Victim: @HoustonBall...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Sep 19 21:58:19 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                        None
# reply_count                                                           0.0
# quote_count                                                           0.0
# text_info                                                     informative
# text_info_conf                                                     0.6333
# text_human                                     other_relevant_information
# text_human_conf                                                    0.6333
#
#                                                                      3987
# id                                                     910262990540242944  \
# text                    Houston was built for cars. What happens when ...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Sep 19 22:03:03 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                           [Harvey]
# entities_urls                                                        True
# user_location                                                 Seattle, WA
# reply_count                                                           0.0
# quote_count                                                           0.0
# text_info                                                     informative
# text_info_conf                                                     0.6746
# text_human                                                 vehicle_damage
# text_human_conf                                                    0.6746
#
#                                                                      3988
# id                                                     910263603533664261  \
# text                    We delivered our relief efforts to Rockport to...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Sep 19 22:05:29 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                             [Tackleberrys, harvey]
# entities_urls                                                       False
# user_location                                              San Marcos, TX
# reply_count                                                           0.0
# quote_count                                                           0.0
# text_info                                                     informative
# text_info_conf                                                     0.6519
# text_human                         rescue_volunteering_or_donation_effort
# text_human_conf                                                    0.6519
#
#                                                                      3989
# id                                                     910265204990029824  \
# text                    Get your parts from the best in the industry, ...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Sep 19 22:11:51 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                           Las Vegas, Nevada
# reply_count                                                           0.0
# quote_count                                                           0.0
# text_info                                                 not_informative
# text_info_conf                                                     0.8131
# text_human                                               not_humanitarian
# text_human_conf                                                    0.8131
#
#                                                                      3990
# id                                                     910268744697397248  \
# text                    3 hats for #HurricaneHarvey fundraiser.  So pr...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Sep 19 22:25:55 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                         [HurricaneHarvey, pugchat]
# entities_urls                                                       False
# user_location                                               Fullerton, CA
# reply_count                                                           0.0
# quote_count                                                           0.0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                         rescue_volunteering_or_donation_effort
# text_human_conf                                                       1.0
#
#                                                                      3991
# id                                                     910269781588299776
# text                    .@UWMadison students in Houston to aid post-Ha...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Sep 19 22:30:02 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                               Madison, Wis.
# reply_count                                                           0.0
# quote_count                                                           0.0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                         rescue_volunteering_or_donation_effort
# text_human_conf                                                       1.0
#
# [16 rows x 3992 columns]

# %%
new_irma.shape
# Out:
# (3992, 16)

# %% [markdown]
# Se procede a visualizar estos valores para poder analizarlos.
#
# Primero se analiza la cantidad de citas, favoritos, respuestas y retweets, observandolo como histogramas y sus valores ¿?.

# %%
def hist_interaction(df):
    print(df[['quote_count', 'favorite_count', 'reply_count', 'retweet_count']].describe())
    new_df = df[df['retweet_count'] > 50]
    new_df[['quote_count', 'favorite_count', 'reply_count', 'retweet_count']].hist(bins=10)
    return new_df[['quote_count', 'favorite_count', 'reply_count', 'retweet_count']]
a = hist_interaction(new_irma)
print(a)
# Out:
#        quote_count  favorite_count  reply_count  retweet_count
# count  3680.000000     3992.000000  3680.000000    3992.000000
# mean      1.899457       59.466182     2.164946      27.974950
# std      28.901003     1203.834155    64.620760     580.526633
# min       0.000000        0.000000     0.000000       0.000000
# 25%       0.000000        0.000000     0.000000       0.000000
# 50%       0.000000        0.000000     0.000000       0.000000
# 75%       0.000000        0.000000     0.000000       0.000000
# max    1026.000000    43273.000000  3797.000000   25263.000000
#       quote_count  favorite_count  reply_count  retweet_count
# 3             NaN           30970          NaN          25263
# 5             NaN            9042          NaN           4404
# 17            NaN             686          NaN            278
# 19            NaN              35          NaN             69
# 20            NaN             207          NaN             96
# ...           ...             ...          ...            ...
# 2952         10.0             240          2.0            121
# 3045          9.0             150          4.0            129
# 3472        400.0           12197         62.0           4915
# 3614          7.0              65          3.0             70
# 3985          7.0             239          1.0            105
#
# [106 rows x 4 columns]

# %% [markdown]
# Se intenta contabilizar el resto de los valores donde se permite, como si el tweet es sensitivo, si es una cita o si tiene un url anexado.

# %%
def count_booleans(df):
    valores_T = 0
    valores_F = 0
    quoteable = 0
    not_quotable = 0
    url = 0
    urlnt = 0

    for i in range(df.shape[0]):
        if df["possibly_sensitive"][i]:
            valores_T +=1
        else:
            valores_F +=1

        if df["is_quote_status"][i]:
            quoteable += 1
        else:
            not_quotable += 1        

        if df["entities_urls"][i]:
            url += 1
        else:
            urlnt += 1

    plt.bar(["Posible Sensitivo","Posible no Sensitivo"],[valores_T, valores_F])
    plt.show()

    plt.bar(["Es Quote","No Es Quote"],[quoteable, not_quotable])
    plt.show()

    plt.bar(["Url Anexado","Url no Anexado"],[url, urlnt])
    plt.show()

count_booleans(new_irma)

# %% [markdown]
# Se procede a analizar los tweets si son informativos y si son humanitarios. Se separan en grupos según el valor 'conf'. Si 'conf' es 1, se grafican los valores como tal. Si 'conf' es menor a 1, se gráfica junto al promedio de conf.

# %%
def info_and_human(df):
    
    #se copia la dataframe
    df_info = df.copy()
    df_human = df.copy()

    #se borran los archivos NaN correspondientes
    df_info = df_info[df_info['text_info'].notna()]
    df_info = df_info[df_info['text_info_conf'].notna()]
    df_human = df_human[df_human['text_human'].notna()]
    df_human = df_human[df_human['text_human_conf'].notna()]

    #se reinicia la index si necesario
    df_info.reset_index(inplace=True, drop=True)
    df_human.reset_index(inplace=True, drop=True)

    #se crea nueva id según index
    df_info["new_id"] = df_info.index
    df_human["new_id"] = df_human.index

    
    #se crean dataframes para separar conf=1 con conf<1
    info_confiable = df_info[["new_id", "id", "text_info", "text_info_conf"]].copy()
    info_casi_confiable = df_info[["new_id", "id", "text_info", "text_info_conf"]].copy()

    wanted = []
    not_wanted = []

    i = 0
    while i < info_confiable.shape[0]:
        #print(info_confiable["text_info_conf"][i])
        if info_confiable["text_info_conf"][i] < 1:
            not_wanted.append(info_confiable["new_id"][i])
        else:
            wanted.append(info_confiable["new_id"][i])
        i += 1


    for j in not_wanted:
        info_confiable = info_confiable.drop(info_confiable[info_confiable["new_id"]==j].index)

    for k in wanted:
        info_casi_confiable = info_casi_confiable.drop(info_casi_confiable[info_casi_confiable["new_id"]==k].index)


    #se crean dataframes para separar conf=1 con conf<1
    human_confiable = df_human[["new_id", "id", "text_human", "text_human_conf"]].copy()
    human_casi_confiable = df_human[["new_id", "id", "text_human", "text_human_conf"]].copy()

    hwanted = []
    not_hwanted = []

    i = 0
    while i < human_confiable.shape[0]:
        #print(info_confiable["text_info_conf"][i])
        if human_confiable["text_human_conf"][i] < 1:
            not_hwanted.append(human_confiable["new_id"][i])
        else:
            hwanted.append(human_confiable["new_id"][i])
        i += 1


    for j in not_hwanted:
        human_confiable = human_confiable.drop(human_confiable[human_confiable["new_id"]==j].index)

    for k in hwanted:
        human_casi_confiable = human_casi_confiable.drop(human_casi_confiable[human_casi_confiable["new_id"]==k].index)


    valores_info_confiable = info_confiable["text_info"].value_counts()

    plt.bar(valores_info_confiable.index, valores_info_confiable.values)

    plt.xlabel("")
    plt.ylabel("")
    plt.title("")

    plt.show()

    valores_human_confiable = human_confiable["text_human"].value_counts()

    plt.bar(valores_human_confiable.index, valores_human_confiable.values)

    for i, v in enumerate(valores_human_confiable.values):
        plt.text(i, v + 1, str(v), ha="center")

    plt.xlabel("")
    plt.ylabel("")
    plt.title("")

    plt.xticks(rotation=90)

    plt.show()


    # calculate counts and means
    counts = info_casi_confiable['text_info'].value_counts().sort_index()
    means = info_casi_confiable.groupby('text_info')['text_info_conf'].mean().sort_index()

    # plot the bar chart
    fig, ax = plt.subplots(figsize=(8,6))
    counts.plot(kind='bar', color='blue', width=0.4, position=0, ax=ax)
    means.plot(kind='bar', color='red', width=0.4, position=1, ax=ax)

    # add labels
    ax.set_xlabel('Categorical Value')
    ax.set_ylabel('Count / Mean Reliability')
    ax.set_title('Count and Mean Reliability by Categorical Value')

    # add value labels
    for i, count in enumerate(counts):
        ax.text(i-0.2, count+0.1, str(count), color='black', fontweight='bold')
    for i, mean in enumerate(means):
        ax.text(i+0.2, mean+0.02, f'{mean:.2f}', color='black', ha='center')

    # calculate counts and means
    counts = human_casi_confiable['text_human'].value_counts().sort_index()
    means = human_casi_confiable.groupby('text_human')['text_human_conf'].mean().sort_index()

    # plot the bar chart
    fig, ax = plt.subplots(figsize=(8,6))
    counts.plot(kind='bar', color='blue', width=0.4, position=0, ax=ax)
    means.plot(kind='bar', color='red', width=0.4, position=1, ax=ax)

    # add labels
    ax.set_xlabel('Categorical Value')
    ax.set_ylabel('Count / Mean Reliability')
    ax.set_title('Count and Mean Reliability by Categorical Value')

    # add value labels
    for i, count in enumerate(counts):
        ax.text(i-0.2, count+0.1, str(count), color='black', fontweight='bold')
    for i, mean in enumerate(means):
        ax.text(i+0.2, mean+0.02, f'{mean:.2f}', color='black', ha='center')

info_and_human(new_irma)

# %% [markdown]
# Se procede a observar el texto de cada tweet. Se contabilizan las palabras usadas para buscar las más repetidas.

# %%
def count_words(L, n):
    words = []
    for text in list(L): 
        for word in str(text).split():
            #Aca se filtran las palabras que se repiten con mayusculas
            wl = re.sub(r'[\W_]+', '', word.lower())
            # california. -> california
            if word in ['US','USA', 'usa', 'Usa']:
                words.append('USA')
            
            elif wl == "":   
                pass
        
            elif word.lower()[:-2] == "'s":
                words.append(wl[0:-1])

            elif word.lower() != wl:
                words.append(wl)
    
            else:
                words.append(word.lower())

    counter_words = Counter(words)
    pairs = counter_words.most_common(n)
    return pairs

def filter_count_words(L,n):
    stop_words = set(stopwords.words('english'))
    stop_words.add('-')
    stop_words.add('&amp;')
    stop_words.add('|')
    a=count_words(L,n)
    filtered = []
    for word in range(len(a)-1):
        if a[word][0].lower() not in stop_words:
            filtered.append(a[word])
    return filtered

def graficar_palabras(pares):
    words = [par[0] for par in pares]
    frequencies = [par[1] for par in pares]
    
    fig, ax = plt.subplots()

    ax.bar(words, frequencies)
    ax.set_xlabel('Palabras')
    ax.set_ylabel('Frecuencia')
    ax.set_title('Frecuencia de palabras')
    ax.legend(['Frecuencia'])    
    ax.tick_params(axis='x', labelrotation=90)  
    fig.set_size_inches(15, 6)
    plt.show()

graficar_palabras(filter_count_words(irma['text'], 50))

# %%
def boxplots(df):
    df_0 = df[df['retweet_count'] > 0]
    df_0[['favorite_count', 'retweet_count']].plot(kind='box')
    df_0[['quote_count', 'reply_count']].plot(kind='box')
boxplots(irma)

# %% [markdown]
# |               | favorite_count | retweet_count | reply_count | quote_count | text_info_conf | text_human_conf |
# |---------------|---------------|---------------|-------------|-------------|----------------|----------------|
# | count         | 15224         | 15224         | 14911       | 14912       | 13146          | 13146          |
# | mean          | 40.85         | 21.02         | 1.59        | 2.52        | 0.79           | 0.79           |
# | std           | 860.53        | 472.87        | 37.78       | 61.16       | 0.20           | 0.20           |
# | min           | 0             | 0             | 0           | 0           | 0.26           | 0.26           |
# | 25%           | 0             | 0             | 0           | 0           | 0.66           | 0.66           |
# | 50%           | 0             | 0             | 0           | 0           | 0.70           | 0.70           |
# | 75%           | 0             | 0             | 0           | 0           | 1.00           | 1.00           |
# | max           | 51726         | 36840         | 3797        | 4010        | 1.00           | 1.00           |
