# %% [markdown]
# # Análisis de los datos relacionado al Huracán Irma
# Se comienza con los imports

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import regex as re
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\steve\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Se definen funciones necesarias para extraer los datos del archivo .json y .tsv

# %%
def get_hashtags_text(x):
    if pd.notna(x) and 'hashtags' in x and x['hashtags']:
        hashtags = x['hashtags']
        hashtags_text = [ht['text'] for ht in hashtags]
        return hashtags_text
    else:
        return None

def get_urls(x):
    if pd.notna(x) and 'urls' in x and x['urls']:
        return True
    return False


def get_user_location(x):
    if pd.notna(x) and 'location' in x:
        return x['location']
    else:
        return None


  
def load_json_old(file_path):
    """
    Carga un archivo JSON en un DataFrame de Pandas.

    Args:
        file_path (str): Ruta del archivo JSON.

    Returns:
        pandas.DataFrame: DataFrame con los datos del archivo JSON.
    """
    # Crear un nuevo DataFrame vacío
    df_new = pd.DataFrame()

    try:
        # Leer el archivo JSON línea por línea y cargar los datos en una lista
        datos_json = []
        with open(file_path, "r", encoding="utf-8") as f:
            for line in f:
                data = json.loads(line)
                datos_json.append(data)

        # Convertir la lista de datos en un DataFrame de Pandas
        df = pd.DataFrame(datos_json)

        # Actualizar las columnas del nuevo DataFrame con los datos válidos
        df_new['id'] = df['id']
        df_new['lang'] = df['lang']
        df_new['text'] = df['text']
        df_new['favorite_count'] = df['favorite_count']
        df_new['retweet_count'] = df['retweet_count']
        df_new['possibly_sensitive'] = df['possibly_sensitive']
        df_new['created_at'] = df['created_at']
        df_new['is_quote_status'] = df['is_quote_status']
        df_new = df_new[df['retweeted_status'].isna()]
        df_new['entities_hashtags_text'] = df['entities'].apply(get_hashtags_text)
        df_new['entities_urls'] = df['entities'].apply(get_urls)
        df_new['user_location'] = df['user'].apply(get_user_location)

        # Manejar la excepción de KeyError para las columnas opcionales
        try:
            df_new['reply_count'] = df['reply_count']
            df_new['quote_count'] = df['quote_count']
        except KeyError as e:
            print(f'Una o más columnas no existen en el archivo JSON: {e}')

        # Eliminar las columnas "user" y "entities"
        #df_new.drop(['user', 'entities'], axis=1, inplace=True)

    except Exception as e:
        print(f'Se produjo una excepción: {e}')

    # Retornar el DataFrame resultante
    return df_new

def load_json2(file_path):
    """
    Carga un archivo JSON en un DataFrame de Pandas.

    Args:
        file_path (str): Ruta del archivo JSON.

    Returns:
        pandas.DataFrame: DataFrame con los datos del archivo JSON.
    """
    # Leer el archivo JSON línea por línea y cargar los datos en una lista
    datos_json = []
    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            data = json.loads(line)
            if 'retweeted_status' in data and data['retweeted_status'] != None:
                data = data['retweeted_status']
            datos_json.append(data)

    # Convertir la lista de datos en un DataFrame de Pandas
    df = pd.DataFrame(datos_json)

    # Crear un nuevo DataFrame con las columnas deseadas
    df_new = df[['id','lang','text','favorite_count','quote_count','reply_count','retweet_count', 'possibly_sensitive','created_at',
                    'entities', 'is_quote_status',
                'user']]


    # Filtrar las filas donde "retweeted_status" no sea None o NaN
    #df_new = df_new[df['retweeted_status'].isna()]

    # Extraer la información de los hashtags, URLs y ubicación de usuario y agregarla como nuevas columnas
    df_new['entities_hashtags_text'] = df_new['entities'].apply(get_hashtags_text).apply(lambda x: x if x else None)
    df_new['entities_urls'] = df_new['entities'].apply(get_urls)
    df_new['user_location'] = df_new['user'].apply(get_user_location)

    # Eliminar las columnas "user" y "entities"
    df_new.drop(['user', 'entities'], axis=1, inplace=True)

    # Retornar el DataFrame resultante
    return df_new

def load_json(file_path):
  
    df_new = pd.DataFrame()

    try:
        # Leer el archivo JSON línea por línea y cargar los datos en una lista
        datos_json = []
        with open(file_path, "r", encoding="utf-8") as f:
            for line in f:
                data = json.loads(line)
                if 'retweeted_status' in data and data['retweeted_status'] != None:
                    data = data['retweeted_status']
                datos_json.append(data)

      
        df = pd.DataFrame(datos_json)

        df_new['id'] = df['id']
        df_new['lang'] = df['lang']
        df_new['text'] = df['text']
        df_new['favorite_count'] = df['favorite_count']
        df_new['retweet_count'] = df['retweet_count']
        df_new['possibly_sensitive'] = df['possibly_sensitive']
        df_new['created_at'] = df['created_at']
        df_new['is_quote_status'] = df['is_quote_status']
        df_new['entities_hashtags_text'] = df['entities'].apply(get_hashtags_text)
        df_new['entities_urls'] = df['entities'].apply(get_urls)
        df_new['user_location'] = df['user'].apply(get_user_location)
        try:
            df_new['reply_count'] = df['reply_count']
            df_new['quote_count'] = df['quote_count']
        except KeyError as e:
            print(f'Una o más columnas no existen en el archivo JSON: {e}')
    except Exception as e:
        print(f'Se produjo una excepción: {e}')

    # Retornar el DataFrame resultante
    return df_new

# %% [markdown]
# Se crea la dataframe sobre el Irma

# %%
irma_json = load_json("RDATA/CrisisMMD_v2.0/json/california_wildfires_final_data.json")
irma_tsv = pd.read_table("RDATA/CrisisMMD_v2.0/annotations/california_wildfires_final_data.tsv")

irma = pd.merge(irma_json, irma_tsv[['tweet_id', 'text_info', 'text_info_conf', 'text_human', 'text_human_conf']],
                    left_on='id', right_on='tweet_id', how='left')
irma.drop('tweet_id',axis=1,inplace=True)
irma.T
# Out:
#                                                                      0
# id                                                     917791130590183424  \
# lang                                                                   en
# text                    PHOTOS: Deadly wildfires rage in California ht...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Oct 10 16:37:11 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                             Portland, Maine
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                              infrastructure_and_utility_damage
# text_human_conf                                                       1.0
#
#                                                                      1
# id                                                     917787635946524674  \
# lang                                                                   en
# text                    Wildfires raging through Northern California a...
# favorite_count                                                          7
# retweet_count                                                           5
# possibly_sensitive                                                  False
# created_at                                 Tue Oct 10 16:23:18 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                        None
# reply_count                                                             0
# quote_count                                                             4
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                      2
# id                                                     917500054742605829  \
# lang                                                                   en
# text                    PLS SHARE: We’re capturing wildfire response, ...
# favorite_count                                                        289
# retweet_count                                                         479
# possibly_sensitive                                                  False
# created_at                                 Mon Oct 09 21:20:34 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                      Sacramento, California
# reply_count                                                             9
# quote_count                                                            25
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                      3
# id                                                     917623252264062976  \
# lang                                                                   en
# text                    California's raging wildfires as you've never ...
# favorite_count                                                        228
# retweet_count                                                         216
# possibly_sensitive                                                  False
# created_at                                 Tue Oct 10 05:30:06 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                        None
# reply_count                                                            19
# quote_count                                                            18
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                      4
# id                                                     917792930315821057  \
# lang                                                                   en
# text                    Mass Evacuations in California as Wildfires Ki...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Oct 10 16:44:21 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                              [CaliforniaWildfires]
# entities_urls                                                        True
# user_location                              www.facebook.com/doctorreefer/
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                                         injured_or_dead_people
# text_human_conf                                                       1.0
#
#                                                                      5
# id                                                     917792147700465664  \
# lang                                                                   en
# text                    Wildfires Threaten California’s First Legal Ca...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Oct 10 16:41:14 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                               United States
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.7143
# text_human                                     other_relevant_information
# text_human_conf                                                    0.7143
#
#                                                                      6
# id                                                     917715928271507456  \
# lang                                                                   en
# text                    Southern California fire shrouds Disneyland An...
# favorite_count                                                        133
# retweet_count                                                          76
# possibly_sensitive                                                  False
# created_at                                 Tue Oct 10 11:38:22 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                      U.S.A.
# reply_count                                                            25
# quote_count                                                             7
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                      7
# id                                                     917794232160661505  \
# lang                                                                   en
# text                    At Least 11 Dead and 100 Missing as Wildfires ...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Oct 10 16:49:31 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                       False
# user_location                                         Not Trump's America
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                                         injured_or_dead_people
# text_human_conf                                                       1.0
#
#                                                                      8
# id                                                     917433167014920192  \
# lang                                                                   en
# text                    California wildfires destroy more than 50 stru...
# favorite_count                                                          1
# retweet_count                                                           2
# possibly_sensitive                                                  False
# created_at                                 Mon Oct 09 16:54:46 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                         [KAKEnews]
# entities_urls                                                        True
# user_location                                             Wichita, Kansas
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                    9     ...
# id                                                   917793736918216706  ...  \
# lang                                                                 en  ...
# text                    California wildfire. ὡ4 https://t.co/a8oD5rkDdI  ...
# favorite_count                                                        0  ...
# retweet_count                                                         0  ...
# possibly_sensitive                                                False  ...
# created_at                               Tue Oct 10 16:47:33 +0000 2017  ...
# is_quote_status                                                   False  ...
# entities_hashtags_text                                             None  ...
# entities_urls                                                     False  ...
# user_location                                                New Jersey  ...
# reply_count                                                           0  ...
# quote_count                                                           0  ...
# text_info                                               not_informative  ...
# text_info_conf                                                   0.6535  ...
# text_human                                             not_humanitarian  ...
# text_human_conf                                                  0.6535  ...
#
#                                                                      1559
# id                                                     923725791086526466  \
# lang                                                                   en
# text                    Go to https://t.co/MDFk59X16v and grab a shirt...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Fri Oct 27 01:39:25 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                    Berkeley
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                         rescue_volunteering_or_donation_effort
# text_human_conf                                                       1.0
#
#                                                                      1560
# id                                                     923727709641084928  \
# lang                                                                   en
# text                    California Wildfires Toll:  42 Dead, $1 Billio...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Fri Oct 27 01:47:02 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                         [Survival]
# entities_urls                                                        True
# user_location                                                        None
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.6567
# text_human                                         injured_or_dead_people
# text_human_conf                                                    0.6567
#
#                                                                      1561
# id                                                     923731648033669121  \
# lang                                                                   en
# text                    Wildfires in California - Brush Fire in Anahei...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Fri Oct 27 02:02:41 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                  seattle,WA
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.6608
# text_human                              infrastructure_and_utility_damage
# text_human_conf                                                    0.6608
#
#                                                                      1562
# id                                                     923743588260880384  \
# lang                                                                   en
# text                    Montana fire crews back from California https:...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Fri Oct 27 02:50:08 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                     Montana
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                 not_informative
# text_info_conf                                                     0.6907
# text_human                                               not_humanitarian
# text_human_conf                                                    0.6907
#
#                                                                      1563
# id                                                     923760012735938560  \
# lang                                                                   en
# text                    Hear from one Sulphur native who survived the ...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Fri Oct 27 03:55:24 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                            Lake Charles, LA
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.6865
# text_human                                           affected_individuals
# text_human_conf                                                    0.6865
#
#                                                                      1564
# id                                                     923761170967797761  \
# lang                                                                   en
# text                    GOP targets environmental rules after Californ...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Fri Oct 27 04:00:00 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                   Washington, DC · 103.5 FM
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.6495
# text_human                                     other_relevant_information
# text_human_conf                                                    0.6495
#
#                                                                      1565
# id                                                     923796193670336512  \
# lang                                                                   en
# text                    Motorcycle crash sparked 350-acre fire in Clev...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Fri Oct 27 06:19:10 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                       [california]
# entities_urls                                                        True
# user_location                                 San Luis Obispo, California
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.3706
# text_human                                     other_relevant_information
# text_human_conf                                                    0.3706
#
#                                                                      1566
# id                                                     923821955568013313  \
# lang                                                                   en
# text                    Carl’s Jr. #SantaRosa catches #Fire while maki...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Fri Oct 27 08:01:32 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                         [SantaRosa, Fire, Burgers]
# entities_urls                                                        True
# user_location                                                        None
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                 not_informative
# text_info_conf                                                     0.6634
# text_human                                               not_humanitarian
# text_human_conf                                                    0.6634
#
#                                                                      1567
# id                                                     923844053426348032  \
# lang                                                                   en
# text                    Inside the List: The Romance Writer Who Almost...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Fri Oct 27 09:29:21 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                             Agate, Colorado
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.6763
# text_human                                     other_relevant_information
# text_human_conf                                                    0.6763
#
#                                                                      1568
# id                                                     923879231175630848
# lang                                                                   en
# text                    How long will heat, wildfire threat persist in...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Fri Oct 27 11:49:08 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                   São Paulo
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                 not_informative
# text_info_conf                                                     0.6534
# text_human                                               not_humanitarian
# text_human_conf                                                    0.6534
#
# [17 rows x 1569 columns]

# %% [markdown]
# Se revisa su tamaño y que cotiene

# %%
irma.shape
# Out:
# (1569, 17)

# %%
summary = irma.describe()
print(summary)
# Out:
#                  id  favorite_count  retweet_count  reply_count  quote_count
# count  1.569000e+03     1569.000000    1569.000000  1569.000000  1569.000000  \
# mean   9.193355e+17        2.040153       1.873805     0.237731     0.189930
# std    1.331323e+16       15.920892      16.791014     1.862000     1.379839
# min    5.800679e+17        0.000000       0.000000     0.000000     0.000000
# 25%    9.181113e+17        0.000000       0.000000     0.000000     0.000000
# 50%    9.199711e+17        0.000000       0.000000     0.000000     0.000000
# 75%    9.210667e+17        0.000000       0.000000     0.000000     0.000000
# max    9.238792e+17      289.000000     479.000000    25.000000    25.000000
#
#        text_info_conf  text_human_conf
# count     1453.000000      1453.000000
# mean         0.802372         0.802372
# std          0.195791         0.195791
# min          0.333300         0.333300
# 25%          0.664300         0.664300
# 50%          0.688400         0.688400
# 75%          1.000000         1.000000
# max          1.000000         1.000000

# %%
# select only numerical columns
numerical_columns = irma.select_dtypes(include=['int64', 'float64']).columns.tolist()

# select only non-numerical columns
categorical_columns = irma.select_dtypes(include=['object']).columns.tolist()

boolean_columns = irma.select_dtypes(include=['bool']).columns.tolist()

print(numerical_columns)

print(categorical_columns)

print(boolean_columns)
# Out:
# ['id', 'favorite_count', 'retweet_count', 'reply_count', 'quote_count', 'text_info_conf', 'text_human_conf']
# ['lang', 'text', 'created_at', 'entities_hashtags_text', 'user_location', 'text_info', 'text_human']
# ['possibly_sensitive', 'is_quote_status', 'entities_urls']

# %% [markdown]
# Se revisa si hay ids duplicadas, y si existen, eliminar esas filas del dataframe

# %%
irma["id"].value_counts()
# Out:
# id
# 922144749632479232    4
# 920831780629782528    4
# 921095476455321600    4
# 920916661519007745    4
# 917991257594572800    4
#                      ..
# 919461628260814848    1
# 919594796280307712    1
# 919594745734631429    1
# 919325735742988288    1
# 923879231175630848    1
# Name: count, Length: 1486, dtype: int64

# %%
irma = irma.drop_duplicates(subset=['id']).reset_index(drop=True)
irma
# Out:
#                       id lang
# 0     917791130590183424   en  \
# 1     917787635946524674   en
# 2     917500054742605829   en
# 3     917623252264062976   en
# 4     917792930315821057   en
# ...                  ...  ...
# 1481  923761170967797761   en
# 1482  923796193670336512   en
# 1483  923821955568013313   en
# 1484  923844053426348032   en
# 1485  923879231175630848   en
#
#                                                    text  favorite_count
# 0     PHOTOS: Deadly wildfires rage in California ht...               0  \
# 1     Wildfires raging through Northern California a...               7
# 2     PLS SHARE: We’re capturing wildfire response, ...             289
# 3     California's raging wildfires as you've never ...             228
# 4     Mass Evacuations in California as Wildfires Ki...               0
# ...                                                 ...             ...
# 1481  GOP targets environmental rules after Californ...               0
# 1482  Motorcycle crash sparked 350-acre fire in Clev...               0
# 1483  Carl’s Jr. #SantaRosa catches #Fire while maki...               0
# 1484  Inside the List: The Romance Writer Who Almost...               0
# 1485  How long will heat, wildfire threat persist in...               0
#
#       retweet_count  possibly_sensitive                      created_at
# 0                 0               False  Tue Oct 10 16:37:11 +0000 2017  \
# 1                 5               False  Tue Oct 10 16:23:18 +0000 2017
# 2               479               False  Mon Oct 09 21:20:34 +0000 2017
# 3               216               False  Tue Oct 10 05:30:06 +0000 2017
# 4                 0               False  Tue Oct 10 16:44:21 +0000 2017
# ...             ...                 ...                             ...
# 1481              0               False  Fri Oct 27 04:00:00 +0000 2017
# 1482              0               False  Fri Oct 27 06:19:10 +0000 2017
# 1483              0               False  Fri Oct 27 08:01:32 +0000 2017
# 1484              0               False  Fri Oct 27 09:29:21 +0000 2017
# 1485              0               False  Fri Oct 27 11:49:08 +0000 2017
#
#       is_quote_status      entities_hashtags_text  entities_urls
# 0               False                        None           True  \
# 1               False                        None           True
# 2               False                        None           True
# 3               False                        None           True
# 4               False       [CaliforniaWildfires]           True
# ...               ...                         ...            ...
# 1481            False                        None           True
# 1482            False                [california]           True
# 1483            False  [SantaRosa, Fire, Burgers]           True
# 1484            False                        None           True
# 1485            False                        None           True
#
#                        user_location  reply_count  quote_count
# 0                    Portland, Maine            0            0  \
# 1                               None            0            4
# 2             Sacramento, California            9           25
# 3                               None           19           18
# 4     www.facebook.com/doctorreefer/            0            0
# ...                              ...          ...          ...
# 1481       Washington, DC · 103.5 FM            0            0
# 1482     San Luis Obispo, California            0            0
# 1483                            None            0            0
# 1484                 Agate, Colorado            0            0
# 1485                       São Paulo            0            0
#
#             text_info  text_info_conf                         text_human
# 0         informative          1.0000  infrastructure_and_utility_damage  \
# 1                 NaN             NaN                                NaN
# 2                 NaN             NaN                                NaN
# 3                 NaN             NaN                                NaN
# 4         informative          1.0000             injured_or_dead_people
# ...               ...             ...                                ...
# 1481      informative          0.6495         other_relevant_information
# 1482      informative          0.3706         other_relevant_information
# 1483  not_informative          0.6634                   not_humanitarian
# 1484      informative          0.6763         other_relevant_information
# 1485  not_informative          0.6534                   not_humanitarian
#
#       text_human_conf
# 0              1.0000
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4              1.0000
# ...               ...
# 1481           0.6495
# 1482           0.3706
# 1483           0.6634
# 1484           0.6763
# 1485           0.6534
#
# [1486 rows x 17 columns]

# %% [markdown]
# Con los datos no duplicados, se revisa la variedad de ciertas columnas. Si estás columnas solo retornan un único valor, se eliminan por redundancia.

# %%
language = irma["lang"]

wa = []

for i in language:
    if i not in wa:
        wa.append(i)

print(wa)
# Out:
# ['en']

# %%
favorite = irma["favorite_count"]
RT = irma["retweet_count"]

i = 0

no_fav = []
no_RT = []

while i < len(favorite):
    if favorite[i]== 0:
        no_fav.append("NO")
    if RT[i] == 0:
        no_RT.append("NO")


    i +=1

print(len(favorite))
print(len(no_fav))
print(len(RT))
print(len(no_RT))
# Out:
# 1486
# 1395
# 1486
# 1370

# %%
reply = irma["reply_count"]
quotes = irma["quote_count"]

i=0

no_reply = []
no_quote = []

while i<len(reply):
    if reply[i] == 0:
        no_reply.append("NO")
    if quotes[i] == 0 :
        no_quote.append("NO")
    i += 1

print(len(reply))
print(len(no_reply))
print(len(quotes))
print(len(no_quote))
# Out:
# 1486
# 1433
# 1486
# 1427

# %%
is_quote = irma["is_quote_status"]

is_not_quote = []

i = 0
while i<len(is_quote):
    if not is_quote[i]:
        is_not_quote.append("AAA")
    i+=1

print(len(is_quote))
print(len(is_not_quote))
# Out:
# 1486
# 1475

# %%
is_sensitive = irma["possibly_sensitive"]

is_not_sensitive= []

i = 0
while i<len(is_sensitive):
    if not is_sensitive[i]:
        is_not_sensitive.append("AAA")
    i+=1

print(len(is_sensitive))
print(len(is_not_sensitive))
# Out:
# 1486
# 1476

# %% [markdown]
# Se descubre que todos los tweets son en inglés, por lo que se elimina la columna "lang". El resto de los datos presenta algo de variedad, por lo que se mantienen.

# %%
new_irma = irma.drop(["lang"], axis=1)
new_irma.T
# Out:
#                                                                      0
# id                                                     917791130590183424  \
# text                    PHOTOS: Deadly wildfires rage in California ht...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Oct 10 16:37:11 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                             Portland, Maine
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                              infrastructure_and_utility_damage
# text_human_conf                                                       1.0
#
#                                                                      1
# id                                                     917787635946524674  \
# text                    Wildfires raging through Northern California a...
# favorite_count                                                          7
# retweet_count                                                           5
# possibly_sensitive                                                  False
# created_at                                 Tue Oct 10 16:23:18 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                        None
# reply_count                                                             0
# quote_count                                                             4
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                      2
# id                                                     917500054742605829  \
# text                    PLS SHARE: We’re capturing wildfire response, ...
# favorite_count                                                        289
# retweet_count                                                         479
# possibly_sensitive                                                  False
# created_at                                 Mon Oct 09 21:20:34 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                      Sacramento, California
# reply_count                                                             9
# quote_count                                                            25
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                      3
# id                                                     917623252264062976  \
# text                    California's raging wildfires as you've never ...
# favorite_count                                                        228
# retweet_count                                                         216
# possibly_sensitive                                                  False
# created_at                                 Tue Oct 10 05:30:06 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                        None
# reply_count                                                            19
# quote_count                                                            18
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                      4
# id                                                     917792930315821057  \
# text                    Mass Evacuations in California as Wildfires Ki...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Oct 10 16:44:21 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                              [CaliforniaWildfires]
# entities_urls                                                        True
# user_location                              www.facebook.com/doctorreefer/
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                                         injured_or_dead_people
# text_human_conf                                                       1.0
#
#                                                                      5
# id                                                     917792147700465664  \
# text                    Wildfires Threaten California’s First Legal Ca...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Oct 10 16:41:14 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                               United States
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.7143
# text_human                                     other_relevant_information
# text_human_conf                                                    0.7143
#
#                                                                      6
# id                                                     917715928271507456  \
# text                    Southern California fire shrouds Disneyland An...
# favorite_count                                                        133
# retweet_count                                                          76
# possibly_sensitive                                                  False
# created_at                                 Tue Oct 10 11:38:22 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                      U.S.A.
# reply_count                                                            25
# quote_count                                                             7
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                      7
# id                                                     917794232160661505  \
# text                    At Least 11 Dead and 100 Missing as Wildfires ...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Tue Oct 10 16:49:31 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                       False
# user_location                                         Not Trump's America
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                                         injured_or_dead_people
# text_human_conf                                                       1.0
#
#                                                                      8
# id                                                     917433167014920192  \
# text                    California wildfires destroy more than 50 stru...
# favorite_count                                                          1
# retweet_count                                                           2
# possibly_sensitive                                                  False
# created_at                                 Mon Oct 09 16:54:46 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                         [KAKEnews]
# entities_urls                                                        True
# user_location                                             Wichita, Kansas
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                    9     ...
# id                                                   917793736918216706  ...  \
# text                    California wildfire. ὡ4 https://t.co/a8oD5rkDdI  ...
# favorite_count                                                        0  ...
# retweet_count                                                         0  ...
# possibly_sensitive                                                False  ...
# created_at                               Tue Oct 10 16:47:33 +0000 2017  ...
# is_quote_status                                                   False  ...
# entities_hashtags_text                                             None  ...
# entities_urls                                                     False  ...
# user_location                                                New Jersey  ...
# reply_count                                                           0  ...
# quote_count                                                           0  ...
# text_info                                               not_informative  ...
# text_info_conf                                                   0.6535  ...
# text_human                                             not_humanitarian  ...
# text_human_conf                                                  0.6535  ...
#
#                                                                      1476
# id                                                     923725791086526466  \
# text                    Go to https://t.co/MDFk59X16v and grab a shirt...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Fri Oct 27 01:39:25 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                    Berkeley
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                         rescue_volunteering_or_donation_effort
# text_human_conf                                                       1.0
#
#                                                                      1477
# id                                                     923727709641084928  \
# text                    California Wildfires Toll:  42 Dead, $1 Billio...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Fri Oct 27 01:47:02 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                         [Survival]
# entities_urls                                                        True
# user_location                                                        None
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.6567
# text_human                                         injured_or_dead_people
# text_human_conf                                                    0.6567
#
#                                                                      1478
# id                                                     923731648033669121  \
# text                    Wildfires in California - Brush Fire in Anahei...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Fri Oct 27 02:02:41 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                  seattle,WA
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.6608
# text_human                              infrastructure_and_utility_damage
# text_human_conf                                                    0.6608
#
#                                                                      1479
# id                                                     923743588260880384  \
# text                    Montana fire crews back from California https:...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Fri Oct 27 02:50:08 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                     Montana
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                 not_informative
# text_info_conf                                                     0.6907
# text_human                                               not_humanitarian
# text_human_conf                                                    0.6907
#
#                                                                      1480
# id                                                     923760012735938560  \
# text                    Hear from one Sulphur native who survived the ...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Fri Oct 27 03:55:24 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                            Lake Charles, LA
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.6865
# text_human                                           affected_individuals
# text_human_conf                                                    0.6865
#
#                                                                      1481
# id                                                     923761170967797761  \
# text                    GOP targets environmental rules after Californ...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Fri Oct 27 04:00:00 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                   Washington, DC · 103.5 FM
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.6495
# text_human                                     other_relevant_information
# text_human_conf                                                    0.6495
#
#                                                                      1482
# id                                                     923796193670336512  \
# text                    Motorcycle crash sparked 350-acre fire in Clev...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Fri Oct 27 06:19:10 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                       [california]
# entities_urls                                                        True
# user_location                                 San Luis Obispo, California
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.3706
# text_human                                     other_relevant_information
# text_human_conf                                                    0.3706
#
#                                                                      1483
# id                                                     923821955568013313  \
# text                    Carl’s Jr. #SantaRosa catches #Fire while maki...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Fri Oct 27 08:01:32 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                         [SantaRosa, Fire, Burgers]
# entities_urls                                                        True
# user_location                                                        None
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                 not_informative
# text_info_conf                                                     0.6634
# text_human                                               not_humanitarian
# text_human_conf                                                    0.6634
#
#                                                                      1484
# id                                                     923844053426348032  \
# text                    Inside the List: The Romance Writer Who Almost...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Fri Oct 27 09:29:21 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                             Agate, Colorado
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.6763
# text_human                                     other_relevant_information
# text_human_conf                                                    0.6763
#
#                                                                      1485
# id                                                     923879231175630848
# text                    How long will heat, wildfire threat persist in...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Fri Oct 27 11:49:08 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                   São Paulo
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                 not_informative
# text_info_conf                                                     0.6534
# text_human                                               not_humanitarian
# text_human_conf                                                    0.6534
#
# [16 rows x 1486 columns]

# %%
new_irma.shape
# Out:
# (1486, 16)

# %% [markdown]
# Se procede a visualizar estos valores para poder analizarlos.
#
# Primero se analiza la cantidad de citas, favoritos, respuestas y retweets, observandolo como histogramas y sus valores ¿?.

# %%
def hist_interaction(df):
    print(df[['quote_count', 'favorite_count', 'reply_count', 'retweet_count']].describe())
    new_df = df[df['retweet_count'] > 50]
    new_df[['quote_count', 'favorite_count', 'reply_count', 'retweet_count']].hist()

hist_interaction(new_irma)
# Out:
#        quote_count  favorite_count  reply_count  retweet_count
# count  1486.000000     1486.000000  1486.000000    1486.000000
# mean      0.200538        2.154105     0.251009       1.978466
# std       1.417125       16.352261     1.912457      17.247872
# min       0.000000        0.000000     0.000000       0.000000
# 25%       0.000000        0.000000     0.000000       0.000000
# 50%       0.000000        0.000000     0.000000       0.000000
# 75%       0.000000        0.000000     0.000000       0.000000
# max      25.000000      289.000000    25.000000     479.000000

# %% [markdown]
# Se intenta contabilizar el resto de los valores donde se permite, como si el tweet es sensitivo, si es una cita o si tiene un url anexado.

# %%
def count_booleans(df):
    valores_T = 0
    valores_F = 0
    quoteable = 0
    not_quotable = 0
    url = 0
    urlnt = 0

    for i in range(df.shape[0]):
        if df["possibly_sensitive"][i]:
            valores_T +=1
        else:
            valores_F +=1

        if df["is_quote_status"][i]:
            quoteable += 1
        else:
            not_quotable += 1        

        if df["entities_urls"][i]:
            url += 1
        else:
            urlnt += 1

    plt.bar(["Posible Sensitivo","Posible no Sensitivo"],[valores_T, valores_F])
    plt.show()

    plt.bar(["Es Quote","No Es Quote"],[quoteable, not_quotable])
    plt.show()

    plt.bar(["Url Anexado","Url no Anexado"],[url, urlnt])
    plt.show()

count_booleans(new_irma)

# %% [markdown]
# Se procede a analizar los tweets si son informativos y si son humanitarios. Se separan en grupos según el valor 'conf'. Si 'conf' es 1, se grafican los valores como tal. Si 'conf' es menor a 1, se gráfica junto al promedio de conf.

# %%
def info_and_human(df):
    
    #se copia la dataframe
    df_info = df.copy()
    df_human = df.copy()

    #se borran los archivos NaN correspondientes
    df_info = df_info[df_info['text_info'].notna()]
    df_info = df_info[df_info['text_info_conf'].notna()]
    df_human = df_human[df_human['text_human'].notna()]
    df_human = df_human[df_human['text_human_conf'].notna()]

    #se reinicia la index si necesario
    df_info.reset_index(inplace=True, drop=True)
    df_human.reset_index(inplace=True, drop=True)

    #se crea nueva id según index
    df_info["new_id"] = df_info.index
    df_human["new_id"] = df_human.index

    
    #se crean dataframes para separar conf=1 con conf<1
    info_confiable = df_info[["new_id", "id", "text_info", "text_info_conf"]].copy()
    info_casi_confiable = df_info[["new_id", "id", "text_info", "text_info_conf"]].copy()

    wanted = []
    not_wanted = []

    i = 0
    while i < info_confiable.shape[0]:
        #print(info_confiable["text_info_conf"][i])
        if info_confiable["text_info_conf"][i] < 1:
            not_wanted.append(info_confiable["new_id"][i])
        else:
            wanted.append(info_confiable["new_id"][i])
        i += 1


    for j in not_wanted:
        info_confiable = info_confiable.drop(info_confiable[info_confiable["new_id"]==j].index)

    for k in wanted:
        info_casi_confiable = info_casi_confiable.drop(info_casi_confiable[info_casi_confiable["new_id"]==k].index)


    #se crean dataframes para separar conf=1 con conf<1
    human_confiable = df_human[["new_id", "id", "text_human", "text_human_conf"]].copy()
    human_casi_confiable = df_human[["new_id", "id", "text_human", "text_human_conf"]].copy()

    hwanted = []
    not_hwanted = []

    i = 0
    while i < human_confiable.shape[0]:
        #print(info_confiable["text_info_conf"][i])
        if human_confiable["text_human_conf"][i] < 1:
            not_hwanted.append(human_confiable["new_id"][i])
        else:
            hwanted.append(human_confiable["new_id"][i])
        i += 1


    for j in not_hwanted:
        human_confiable = human_confiable.drop(human_confiable[human_confiable["new_id"]==j].index)

    for k in hwanted:
        human_casi_confiable = human_casi_confiable.drop(human_casi_confiable[human_casi_confiable["new_id"]==k].index)


    valores_info_confiable = info_confiable["text_info"].value_counts()

    plt.bar(valores_info_confiable.index, valores_info_confiable.values)

    plt.xlabel("")
    plt.ylabel("")
    plt.title("")

    plt.show()

    valores_human_confiable = human_confiable["text_human"].value_counts()

    plt.bar(valores_human_confiable.index, valores_human_confiable.values)

    for i, v in enumerate(valores_human_confiable.values):
        plt.text(i, v + 1, str(v), ha="center")

    plt.xlabel("")
    plt.ylabel("")
    plt.title("")

    plt.xticks(rotation=90)

    plt.show()


    # calculate counts and means
    counts = info_casi_confiable['text_info'].value_counts().sort_index()
    means = info_casi_confiable.groupby('text_info')['text_info_conf'].mean().sort_index()

    # plot the bar chart
    fig, ax = plt.subplots(figsize=(8,6))
    counts.plot(kind='bar', color='blue', width=0.4, position=0, ax=ax)
    means.plot(kind='bar', color='red', width=0.4, position=1, ax=ax)

    # add labels
    ax.set_xlabel('Categorical Value')
    ax.set_ylabel('Count / Mean Reliability')
    ax.set_title('Count and Mean Reliability by Categorical Value')

    # add value labels
    for i, count in enumerate(counts):
        ax.text(i-0.2, count+0.1, str(count), color='black', fontweight='bold')
    for i, mean in enumerate(means):
        ax.text(i+0.2, mean+0.02, f'{mean:.2f}', color='black', ha='center')

    # calculate counts and means
    counts = human_casi_confiable['text_human'].value_counts().sort_index()
    means = human_casi_confiable.groupby('text_human')['text_human_conf'].mean().sort_index()

    # plot the bar chart
    fig, ax = plt.subplots(figsize=(8,6))
    counts.plot(kind='bar', color='blue', width=0.4, position=0, ax=ax)
    means.plot(kind='bar', color='red', width=0.4, position=1, ax=ax)

    # add labels
    ax.set_xlabel('Categorical Value')
    ax.set_ylabel('Count / Mean Reliability')
    ax.set_title('Count and Mean Reliability by Categorical Value')

    # add value labels
    for i, count in enumerate(counts):
        ax.text(i-0.2, count+0.1, str(count), color='black', fontweight='bold')
    for i, mean in enumerate(means):
        ax.text(i+0.2, mean+0.02, f'{mean:.2f}', color='black', ha='center')

info_and_human(new_irma)

# %% [markdown]
# Se procede a observar el texto de cada tweet. Se contabilizan las palabras usadas para buscar las más repetidas.

# %%
def count_words(L, n):
    words = []
    for text in list(L): 
        for word in str(text).split():
            #Aca se filtran las palabras que se repiten con mayusculas
            wl = re.sub(r'[\W_]+', '', word.lower())
            # california. -> california
            if word in ['US','USA', 'usa', 'Usa']:
                words.append('USA')
            
            elif wl == "":   
                pass
        
            elif word.lower()[:-2] == "'s":
                words.append(wl[0:-1])

            elif word.lower() != wl:
                words.append(wl)
    
            else:
                words.append(word.lower())

    counter_words = Counter(words)
    pairs = counter_words.most_common(n)
    return pairs

def filter_count_words(L,n):
    stop_words = set(stopwords.words('english'))
    stop_words.add('-')
    stop_words.add('&amp;')
    stop_words.add('|')
    a=count_words(L,n)
    filtered = []
    for word in range(len(a)-1):
        if a[word][0].lower() not in stop_words:
            filtered.append(a[word])
    return filtered

def graficar_palabras(pares):
    words = [par[0] for par in pares]
    frequencies = [par[1] for par in pares]
    
    fig, ax = plt.subplots()

    ax.bar(words, frequencies)
    ax.set_xlabel('Palabras')
    ax.set_ylabel('Frecuencia')
    ax.set_title('Frecuencia de palabras')
    ax.legend(['Frecuencia'])    
    ax.tick_params(axis='x', labelrotation=90)  
    fig.set_size_inches(15, 6)
    plt.show()

graficar_palabras(filter_count_words(irma['text'], 90))
