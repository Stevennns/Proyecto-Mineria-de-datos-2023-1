# %% [markdown]
# # Análisis de los datos relacionado al Terremoto Iraq Iran
# Se comienza con los imports

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import regex as re
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\steve\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Se definen funciones necesarias para extraer los datos del archivo .json y .tsv

# %%
def get_hashtags_text(x):
    if pd.notna(x) and 'hashtags' in x and x['hashtags']:
        hashtags = x['hashtags']
        hashtags_text = [ht['text'] for ht in hashtags]
        return hashtags_text
    else:
        return None

def get_urls(x):
    if pd.notna(x) and 'urls' in x and x['urls']:
        return True
    return False


def get_user_location(x):
    if pd.notna(x) and 'location' in x:
        return x['location']
    else:
        return None


  
def load_json_old(file_path):
    """
    Carga un archivo JSON en un DataFrame de Pandas.

    Args:
        file_path (str): Ruta del archivo JSON.

    Returns:
        pandas.DataFrame: DataFrame con los datos del archivo JSON.
    """
    # Crear un nuevo DataFrame vacío
    df_new = pd.DataFrame()

    try:
        # Leer el archivo JSON línea por línea y cargar los datos en una lista
        datos_json = []
        with open(file_path, "r", encoding="utf-8") as f:
            for line in f:
                data = json.loads(line)
                datos_json.append(data)

        # Convertir la lista de datos en un DataFrame de Pandas
        df = pd.DataFrame(datos_json)

        # Actualizar las columnas del nuevo DataFrame con los datos válidos
        df_new['id'] = df['id']
        df_new['lang'] = df['lang']
        df_new['text'] = df['text']
        df_new['favorite_count'] = df['favorite_count']
        df_new['retweet_count'] = df['retweet_count']
        df_new['possibly_sensitive'] = df['possibly_sensitive']
        df_new['created_at'] = df['created_at']
        df_new['is_quote_status'] = df['is_quote_status']
        df_new = df_new[df['retweeted_status'].isna()]
        df_new['entities_hashtags_text'] = df['entities'].apply(get_hashtags_text)
        df_new['entities_urls'] = df['entities'].apply(get_urls)
        df_new['user_location'] = df['user'].apply(get_user_location)

        # Manejar la excepción de KeyError para las columnas opcionales
        try:
            df_new['reply_count'] = df['reply_count']
            df_new['quote_count'] = df['quote_count']
        except KeyError as e:
            print(f'Una o más columnas no existen en el archivo JSON: {e}')

        # Eliminar las columnas "user" y "entities"
        #df_new.drop(['user', 'entities'], axis=1, inplace=True)

    except Exception as e:
        print(f'Se produjo una excepción: {e}')

    # Retornar el DataFrame resultante
    return df_new

def load_json2(file_path):
    """
    Carga un archivo JSON en un DataFrame de Pandas.

    Args:
        file_path (str): Ruta del archivo JSON.

    Returns:
        pandas.DataFrame: DataFrame con los datos del archivo JSON.
    """
    # Leer el archivo JSON línea por línea y cargar los datos en una lista
    datos_json = []
    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            data = json.loads(line)
            if 'retweeted_status' in data and data['retweeted_status'] != None:
                data = data['retweeted_status']
            datos_json.append(data)

    # Convertir la lista de datos en un DataFrame de Pandas
    df = pd.DataFrame(datos_json)

    # Crear un nuevo DataFrame con las columnas deseadas
    df_new = df[['id','lang','text','favorite_count','quote_count','reply_count','retweet_count', 'possibly_sensitive','created_at',
                    'entities', 'is_quote_status',
                'user']]


    # Filtrar las filas donde "retweeted_status" no sea None o NaN
    #df_new = df_new[df['retweeted_status'].isna()]

    # Extraer la información de los hashtags, URLs y ubicación de usuario y agregarla como nuevas columnas
    df_new['entities_hashtags_text'] = df_new['entities'].apply(get_hashtags_text).apply(lambda x: x if x else None)
    df_new['entities_urls'] = df_new['entities'].apply(get_urls)
    df_new['user_location'] = df_new['user'].apply(get_user_location)

    # Eliminar las columnas "user" y "entities"
    df_new.drop(['user', 'entities'], axis=1, inplace=True)

    # Retornar el DataFrame resultante
    return df_new

def load_json(file_path):
  
    df_new = pd.DataFrame()

    try:
        # Leer el archivo JSON línea por línea y cargar los datos en una lista
        datos_json = []
        with open(file_path, "r", encoding="utf-8") as f:
            for line in f:
                data = json.loads(line)
                if 'retweeted_status' in data and data['retweeted_status'] != None:
                    data = data['retweeted_status']
                datos_json.append(data)

      
        df = pd.DataFrame(datos_json)

        df_new['id'] = df['id']
        df_new['lang'] = df['lang']
        df_new['text'] = df['text']
        df_new['favorite_count'] = df['favorite_count']
        df_new['retweet_count'] = df['retweet_count']
        df_new['possibly_sensitive'] = df['possibly_sensitive']
        df_new['created_at'] = df['created_at']
        df_new['is_quote_status'] = df['is_quote_status']
        df_new['entities_hashtags_text'] = df['entities'].apply(get_hashtags_text)
        df_new['entities_urls'] = df['entities'].apply(get_urls)
        df_new['user_location'] = df['user'].apply(get_user_location)
        try:
            df_new['reply_count'] = df['reply_count']
            df_new['quote_count'] = df['quote_count']
        except KeyError as e:
            print(f'Una o más columnas no existen en el archivo JSON: {e}')
    except Exception as e:
        print(f'Se produjo una excepción: {e}')

    # Retornar el DataFrame resultante
    return df_new

# %% [markdown]
# Se crea la dataframe sobre el Irma

# %%
irma_json = load_json("RDATA/CrisisMMD_v2.0/json/iraq_iran_earthquake_final_data.json")
irma_tsv = pd.read_table("RDATA/CrisisMMD_v2.0/annotations/iraq_iran_earthquake_final_data.tsv")

irma = pd.merge(irma_json, irma_tsv[['tweet_id', 'text_info', 'text_info_conf', 'text_human', 'text_human_conf']],
                    left_on='id', right_on='tweet_id', how='left')
irma.drop('tweet_id',axis=1,inplace=True)
irma.T
# Out:
#                                                                       0
# id                                                     929945093804617729  \
# lang                                                                   en
# text                    UPDATE:\nDeath toll from Iran’s quake rises to...
# favorite_count                                                         10
# retweet_count                                                          23
# possibly_sensitive                                                  False
# created_at                                 Mon Nov 13 05:32:42 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                       [earthquake]
# entities_urls                                                       False
# user_location                                                Tehran, Iran
# reply_count                                                             2
# quote_count                                                             1
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                       1
# id                                                     929977545260523520  \
# lang                                                                   en
# text                    We pray for all those affected by the earthqua...
# favorite_count                                                          5
# retweet_count                                                           5
# possibly_sensitive                                                  False
# created_at                                 Mon Nov 13 07:41:39 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                       False
# user_location                                             England & Wales
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                       2
# id                                                     929988832623316993  \
# lang                                                                   en
# text                    JUST IN: Death toll reaches 328 in Iran earthq...
# favorite_count                                                          5
# retweet_count                                                          10
# possibly_sensitive                                                  False
# created_at                                 Mon Nov 13 08:26:30 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                       False
# user_location                                                         NYC
# reply_count                                                             1
# quote_count                                                             2
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                       3
# id                                                     929896865776259072  \
# lang                                                                   en
# text                    A magnitude 7.2 earthquake struck northern Ira...
# favorite_count                                                          2
# retweet_count                                                           3
# possibly_sensitive                                                  False
# created_at                                 Mon Nov 13 02:21:04 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                             [Iraq]
# entities_urls                                                       False
# user_location                                                      Global
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                       4
# id                                                     929989459453595648  \
# lang                                                                   en
# text                    Video: 7.2-magnitude earthquake jolts #Iran-Ir...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Mon Nov 13 08:29:00 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                             [Iran]
# entities_urls                                                        True
# user_location                                                        None
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.6642
# text_human                                     other_relevant_information
# text_human_conf                                                    0.6642
#
#                                                                       5
# id                                                     929989477828911104  \
# lang                                                                   en
# text                    #BREAKING: Iran earthquake toll rises to 328 d...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Mon Nov 13 08:29:04 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                         [BREAKING]
# entities_urls                                                       False
# user_location                                                      Israel
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                                         injured_or_dead_people
# text_human_conf                                                       1.0
#
#                                                                       6
# id                                                     929966930508775424  \
# lang                                                                   en
# text                    Iran-Iraq border earthquake latest:\n- At leas...
# favorite_count                                                         61
# retweet_count                                                         121
# possibly_sensitive                                                  False
# created_at                                 Mon Nov 13 06:59:28 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                        None
# reply_count                                                            14
# quote_count                                                            10
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                       7
# id                                                     929989549895438336  \
# lang                                                                   en
# text                    WSJ: Earthquake near Iran-Iraq border kills mo...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Mon Nov 13 08:29:21 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                   New Delhi
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                                         injured_or_dead_people
# text_human_conf                                                       1.0
#
#                                                                       8
# id                                                     929978536340938754  \
# lang                                                                   en
# text                    Hundreds dead after powerful #earthquake hits ...
# favorite_count                                                         24
# retweet_count                                                          31
# possibly_sensitive                                                  False
# created_at                                 Mon Nov 13 07:45:35 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                       [earthquake]
# entities_urls                                                        True
# user_location                                                        None
# reply_count                                                             4
# quote_count                                                             5
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                       9
# id                                                     929989743810576384  \
# lang                                                                   en
# text                    Turkey rushes to help Iraq earthquake victims ...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Mon Nov 13 08:30:07 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                    Istanbul
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.6686
# text_human                         rescue_volunteering_or_donation_effort
# text_human_conf                                                    0.6686
#
#                         ...
# id                      ...  \
# lang                    ...
# text                    ...
# favorite_count          ...
# retweet_count           ...
# possibly_sensitive      ...
# created_at              ...
# is_quote_status         ...
# entities_hashtags_text  ...
# entities_urls           ...
# user_location           ...
# reply_count             ...
# quote_count             ...
# text_info               ...
# text_info_conf          ...
# text_human              ...
# text_human_conf         ...
#
#                                                                       574
# id                                                     931691151236780037  \
# lang                                                                   en
# text                    The 2017 Iran-Iraq Earthquake from Sentinel-1....
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sat Nov 18 01:10:55 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                       False
# user_location                                                        None
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                                     other_relevant_information
# text_human_conf                                                       1.0
#
#                                                                       575
# id                                                     931771549685899264  \
# lang                                                                   en
# text                    Less than 24 hours after the earthquake hit #I...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sat Nov 18 06:30:23 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                               [Iraq, NiliMajumder]
# entities_urls                                                       False
# user_location                              USA | Europe | Asia | GLOBAL ✈
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                      0.674
# text_human                         rescue_volunteering_or_donation_effort
# text_human_conf                                                     0.674
#
#                                                                       576
# id                                                     931771549685899264  \
# lang                                                                   en
# text                    Less than 24 hours after the earthquake hit #I...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sat Nov 18 06:30:23 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                               [Iraq, NiliMajumder]
# entities_urls                                                       False
# user_location                              USA | Europe | Asia | GLOBAL ✈
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                      0.674
# text_human                         rescue_volunteering_or_donation_effort
# text_human_conf                                                     0.674
#
#                                                                       577
# id                                                     931789781087981568  \
# lang                                                                   en
# text                    14 min.ago #earthquake 3.8 has hit Kerman, Ira...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sat Nov 18 07:42:50 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                       [earthquake]
# entities_urls                                                        True
# user_location                                                       World
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                                     other_relevant_information
# text_human_conf                                                       1.0
#
#                                                                       578
# id                                                     931824949509140480  \
# lang                                                                   en
# text                    IOC voices readiness to help earthquake-affect...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sat Nov 18 10:02:35 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                        None
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.6875
# text_human                         rescue_volunteering_or_donation_effort
# text_human_conf                                                    0.6875
#
#                                                                       579
# id                                                     931880697752567808  \
# lang                                                                   en
# text                    Damage proxy maps of 5 cities near the epicent...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sat Nov 18 13:44:06 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                 [Kermanshah, Iran]
# entities_urls                                                       False
# user_location                                                        None
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.6322
# text_human                              infrastructure_and_utility_damage
# text_human_conf                                                    0.6322
#
#                                                                       580
# id                                                     931898198569996288  \
# lang                                                                   en
# text                    #Iran Daily: US Treasury Blocks Donations for ...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sat Nov 18 14:53:39 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                             [Iran]
# entities_urls                                                        True
# user_location                                                        None
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.6732
# text_human                         rescue_volunteering_or_donation_effort
# text_human_conf                                                    0.6732
#
#                                                                       581
# id                                                     931925410224529410  \
# lang                                                                   en
# text                    #Kurdish children's situation after the #earth...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sat Nov 18 16:41:46 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                        [Kurdish, earthquake, Iran]
# entities_urls                                                       False
# user_location                                                        Iraq
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                                           affected_individuals
# text_human_conf                                                       1.0
#
#                                                                       582
# id                                                     932000082072948736  \
# lang                                                                   en
# text                    #IRAN'S #EARTHQUAKE EXPOSES #POLITICAL RIFTS A...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sat Nov 18 21:38:29 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text          [IRAN, EARTHQUAKE, POLITICAL, GOVERNANCE]
# entities_urls                                                        True
# user_location                                              Washington, DC
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.6827
# text_human                                     other_relevant_information
# text_human_conf                                                    0.6827
#
#                                                                       583
# id                                                     932027639589507072
# lang                                                                   en
# text                    Victims of last week's earthquake gather outdo...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sat Nov 18 23:28:00 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                             [Iran]
# entities_urls                                                       False
# user_location                                        Melbourne, Australia
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                                           affected_individuals
# text_human_conf                                                       1.0
#
# [17 rows x 584 columns]

# %% [markdown]
# Se revisa su tamaño y que cotiene

# %%
irma.shape
# Out:
# (584, 17)

# %%
summary = irma.describe()
print(summary)
# Out:
#                  id  favorite_count  retweet_count  reply_count  quote_count
# count  5.840000e+02      584.000000     584.000000   584.000000   584.000000  \
# mean   9.303919e+17        1.804795       1.986301     0.214041     0.195205
# std    4.858598e+14       10.837625      11.131052     1.633822     1.301633
# min    9.297768e+17        0.000000       0.000000     0.000000     0.000000
# 25%    9.300359e+17        0.000000       0.000000     0.000000     0.000000
# 50%    9.301912e+17        0.000000       0.000000     0.000000     0.000000
# 75%    9.305673e+17        0.000000       0.000000     0.000000     0.000000
# max    9.320276e+17      133.000000     124.000000    30.000000    17.000000
#
#        text_info_conf  text_human_conf
# count      540.000000       540.000000
# mean         0.841564         0.841564
# std          0.188753         0.188753
# min          0.335800         0.335800
# 25%          0.668525         0.668525
# 50%          1.000000         1.000000
# 75%          1.000000         1.000000
# max          1.000000         1.000000

# %%
# select only numerical columns
numerical_columns = irma.select_dtypes(include=['int64', 'float64']).columns.tolist()

# select only non-numerical columns
categorical_columns = irma.select_dtypes(include=['object']).columns.tolist()

boolean_columns = irma.select_dtypes(include=['bool']).columns.tolist()

print(numerical_columns)

print(categorical_columns)

print(boolean_columns)
# Out:
# ['id', 'favorite_count', 'retweet_count', 'reply_count', 'quote_count', 'text_info_conf', 'text_human_conf']
# ['lang', 'text', 'created_at', 'entities_hashtags_text', 'user_location', 'text_info', 'text_human']
# ['possibly_sensitive', 'is_quote_status', 'entities_urls']

# %% [markdown]
# Se revisa si hay ids duplicadas, y si existen, eliminar esas filas del dataframe

# %%
irma["id"].value_counts()
# Out:
# id
# 930205140287741953    4
# 931493766816559104    4
# 930058600160088065    4
# 930523863691288576    4
# 930076476569018368    4
#                      ..
# 930088679141527552    1
# 930086947674116097    1
# 930083870346584064    1
# 930082041386893314    1
# 932027639589507072    1
# Name: count, Length: 496, dtype: int64

# %%
irma = irma.drop_duplicates(subset=['id']).reset_index(drop=True)
irma
# Out:
#                      id lang
# 0    929945093804617729   en  \
# 1    929977545260523520   en
# 2    929988832623316993   en
# 3    929896865776259072   en
# 4    929989459453595648   en
# ..                  ...  ...
# 491  931880697752567808   en
# 492  931898198569996288   en
# 493  931925410224529410   en
# 494  932000082072948736   en
# 495  932027639589507072   en
#
#                                                   text  favorite_count
# 0    UPDATE:\nDeath toll from Iran’s quake rises to...              10  \
# 1    We pray for all those affected by the earthqua...               5
# 2    JUST IN: Death toll reaches 328 in Iran earthq...               5
# 3    A magnitude 7.2 earthquake struck northern Ira...               2
# 4    Video: 7.2-magnitude earthquake jolts #Iran-Ir...               0
# ..                                                 ...             ...
# 491  Damage proxy maps of 5 cities near the epicent...               0
# 492  #Iran Daily: US Treasury Blocks Donations for ...               0
# 493  #Kurdish children's situation after the #earth...               0
# 494  #IRAN'S #EARTHQUAKE EXPOSES #POLITICAL RIFTS A...               0
# 495  Victims of last week's earthquake gather outdo...               0
#
#      retweet_count  possibly_sensitive                      created_at
# 0               23               False  Mon Nov 13 05:32:42 +0000 2017  \
# 1                5               False  Mon Nov 13 07:41:39 +0000 2017
# 2               10               False  Mon Nov 13 08:26:30 +0000 2017
# 3                3               False  Mon Nov 13 02:21:04 +0000 2017
# 4                0               False  Mon Nov 13 08:29:00 +0000 2017
# ..             ...                 ...                             ...
# 491              0               False  Sat Nov 18 13:44:06 +0000 2017
# 492              0               False  Sat Nov 18 14:53:39 +0000 2017
# 493              0               False  Sat Nov 18 16:41:46 +0000 2017
# 494              0               False  Sat Nov 18 21:38:29 +0000 2017
# 495              0               False  Sat Nov 18 23:28:00 +0000 2017
#
#      is_quote_status                     entities_hashtags_text
# 0              False                               [earthquake]  \
# 1              False                                       None
# 2              False                                       None
# 3              False                                     [Iraq]
# 4              False                                     [Iran]
# ..               ...                                        ...
# 491            False                         [Kermanshah, Iran]
# 492            False                                     [Iran]
# 493            False                [Kurdish, earthquake, Iran]
# 494            False  [IRAN, EARTHQUAKE, POLITICAL, GOVERNANCE]
# 495            False                                     [Iran]
#
#      entities_urls         user_location  reply_count  quote_count
# 0            False          Tehran, Iran            2            1  \
# 1            False       England & Wales            0            0
# 2            False                   NYC            1            2
# 3            False                Global            0            0
# 4             True                  None            0            0
# ..             ...                   ...          ...          ...
# 491          False                  None            0            0
# 492           True                  None            0            0
# 493          False                  Iraq            0            0
# 494           True        Washington, DC            0            0
# 495          False  Melbourne, Australia            0            0
#
#        text_info  text_info_conf                              text_human
# 0            NaN             NaN                                     NaN  \
# 1            NaN             NaN                                     NaN
# 2            NaN             NaN                                     NaN
# 3            NaN             NaN                                     NaN
# 4    informative          0.6642              other_relevant_information
# ..           ...             ...                                     ...
# 491  informative          0.6322       infrastructure_and_utility_damage
# 492  informative          0.6732  rescue_volunteering_or_donation_effort
# 493  informative          1.0000                    affected_individuals
# 494  informative          0.6827              other_relevant_information
# 495  informative          1.0000                    affected_individuals
#
#      text_human_conf
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4             0.6642
# ..               ...
# 491           0.6322
# 492           0.6732
# 493           1.0000
# 494           0.6827
# 495           1.0000
#
# [496 rows x 17 columns]

# %% [markdown]
# Con los datos no duplicados, se revisa la variedad de ciertas columnas. Si estás columnas solo retornan un único valor, se eliminan por redundancia.

# %%
language = irma["lang"]

wa = []

for i in language:
    if i not in wa:
        wa.append(i)

print(wa)
# Out:
# ['en']

# %%
favorite = irma["favorite_count"]
RT = irma["retweet_count"]

i = 0

no_fav = []
no_RT = []

while i < len(favorite):
    if favorite[i]== 0:
        no_fav.append("NO")
    if RT[i] == 0:
        no_RT.append("NO")


    i +=1

print(len(favorite))
print(len(no_fav))
print(len(RT))
print(len(no_RT))
# Out:
# 496
# 457
# 496
# 452

# %%
reply = irma["reply_count"]
quotes = irma["quote_count"]

i=0

no_reply = []
no_quote = []

while i<len(reply):
    if reply[i] == 0:
        no_reply.append("NO")
    if quotes[i] == 0 :
        no_quote.append("NO")
    i += 1

print(len(reply))
print(len(no_reply))
print(len(quotes))
print(len(no_quote))
# Out:
# 496
# 473
# 496
# 472

# %%
is_quote = irma["is_quote_status"]

is_not_quote = []

i = 0
while i<len(is_quote):
    if not is_quote[i]:
        is_not_quote.append("AAA")
    i+=1

print(len(is_quote))
print(len(is_not_quote))
# Out:
# 496
# 494

# %%
is_sensitive = irma["possibly_sensitive"]

is_not_sensitive= []

i = 0
while i<len(is_sensitive):
    if not is_sensitive[i]:
        is_not_sensitive.append("AAA")
    i+=1

print(len(is_sensitive))
print(len(is_not_sensitive))
# Out:
# 496
# 489

# %% [markdown]
# Se descubre que todos los tweets son en inglés, por lo que se elimina la columna "lang". El resto de los datos presenta algo de variedad, por lo que se mantienen.

# %%
new_irma = irma.drop(["lang"], axis=1)
new_irma.T
# Out:
#                                                                       0
# id                                                     929945093804617729  \
# text                    UPDATE:\nDeath toll from Iran’s quake rises to...
# favorite_count                                                         10
# retweet_count                                                          23
# possibly_sensitive                                                  False
# created_at                                 Mon Nov 13 05:32:42 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                       [earthquake]
# entities_urls                                                       False
# user_location                                                Tehran, Iran
# reply_count                                                             2
# quote_count                                                             1
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                       1
# id                                                     929977545260523520  \
# text                    We pray for all those affected by the earthqua...
# favorite_count                                                          5
# retweet_count                                                           5
# possibly_sensitive                                                  False
# created_at                                 Mon Nov 13 07:41:39 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                       False
# user_location                                             England & Wales
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                       2
# id                                                     929988832623316993  \
# text                    JUST IN: Death toll reaches 328 in Iran earthq...
# favorite_count                                                          5
# retweet_count                                                          10
# possibly_sensitive                                                  False
# created_at                                 Mon Nov 13 08:26:30 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                       False
# user_location                                                         NYC
# reply_count                                                             1
# quote_count                                                             2
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                       3
# id                                                     929896865776259072  \
# text                    A magnitude 7.2 earthquake struck northern Ira...
# favorite_count                                                          2
# retweet_count                                                           3
# possibly_sensitive                                                  False
# created_at                                 Mon Nov 13 02:21:04 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                             [Iraq]
# entities_urls                                                       False
# user_location                                                      Global
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                       4
# id                                                     929989459453595648  \
# text                    Video: 7.2-magnitude earthquake jolts #Iran-Ir...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Mon Nov 13 08:29:00 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                             [Iran]
# entities_urls                                                        True
# user_location                                                        None
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.6642
# text_human                                     other_relevant_information
# text_human_conf                                                    0.6642
#
#                                                                       5
# id                                                     929989477828911104  \
# text                    #BREAKING: Iran earthquake toll rises to 328 d...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Mon Nov 13 08:29:04 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                         [BREAKING]
# entities_urls                                                       False
# user_location                                                      Israel
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                                         injured_or_dead_people
# text_human_conf                                                       1.0
#
#                                                                       6
# id                                                     929966930508775424  \
# text                    Iran-Iraq border earthquake latest:\n- At leas...
# favorite_count                                                         61
# retweet_count                                                         121
# possibly_sensitive                                                  False
# created_at                                 Mon Nov 13 06:59:28 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                        None
# reply_count                                                            14
# quote_count                                                            10
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                       7
# id                                                     929989549895438336  \
# text                    WSJ: Earthquake near Iran-Iraq border kills mo...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Mon Nov 13 08:29:21 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                   New Delhi
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                                         injured_or_dead_people
# text_human_conf                                                       1.0
#
#                                                                       8
# id                                                     929978536340938754  \
# text                    Hundreds dead after powerful #earthquake hits ...
# favorite_count                                                         24
# retweet_count                                                          31
# possibly_sensitive                                                  False
# created_at                                 Mon Nov 13 07:45:35 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                       [earthquake]
# entities_urls                                                        True
# user_location                                                        None
# reply_count                                                             4
# quote_count                                                             5
# text_info                                                             NaN
# text_info_conf                                                        NaN
# text_human                                                            NaN
# text_human_conf                                                       NaN
#
#                                                                       9
# id                                                     929989743810576384  \
# text                    Turkey rushes to help Iraq earthquake victims ...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Mon Nov 13 08:30:07 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                    Istanbul
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.6686
# text_human                         rescue_volunteering_or_donation_effort
# text_human_conf                                                    0.6686
#
#                         ...
# id                      ...  \
# text                    ...
# favorite_count          ...
# retweet_count           ...
# possibly_sensitive      ...
# created_at              ...
# is_quote_status         ...
# entities_hashtags_text  ...
# entities_urls           ...
# user_location           ...
# reply_count             ...
# quote_count             ...
# text_info               ...
# text_info_conf          ...
# text_human              ...
# text_human_conf         ...
#
#                                                                       486
# id                                                     931664033299738625  \
# text                    @PeterHarley20 @Su39frogfoot @planesonthenet @...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Fri Nov 17 23:23:09 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                       False
# user_location                                                Lugo, España
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                 not_informative
# text_info_conf                                                     0.6943
# text_human                                               not_humanitarian
# text_human_conf                                                    0.6943
#
#                                                                       487
# id                                                     931691151236780037  \
# text                    The 2017 Iran-Iraq Earthquake from Sentinel-1....
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sat Nov 18 01:10:55 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                       False
# user_location                                                        None
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                                     other_relevant_information
# text_human_conf                                                       1.0
#
#                                                                       488
# id                                                     931771549685899264  \
# text                    Less than 24 hours after the earthquake hit #I...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sat Nov 18 06:30:23 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                               [Iraq, NiliMajumder]
# entities_urls                                                       False
# user_location                              USA | Europe | Asia | GLOBAL ✈
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                      0.674
# text_human                         rescue_volunteering_or_donation_effort
# text_human_conf                                                     0.674
#
#                                                                       489
# id                                                     931789781087981568  \
# text                    14 min.ago #earthquake 3.8 has hit Kerman, Ira...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sat Nov 18 07:42:50 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                       [earthquake]
# entities_urls                                                        True
# user_location                                                       World
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                                     other_relevant_information
# text_human_conf                                                       1.0
#
#                                                                       490
# id                                                     931824949509140480  \
# text                    IOC voices readiness to help earthquake-affect...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sat Nov 18 10:02:35 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                               None
# entities_urls                                                        True
# user_location                                                        None
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.6875
# text_human                         rescue_volunteering_or_donation_effort
# text_human_conf                                                    0.6875
#
#                                                                       491
# id                                                     931880697752567808  \
# text                    Damage proxy maps of 5 cities near the epicent...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sat Nov 18 13:44:06 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                 [Kermanshah, Iran]
# entities_urls                                                       False
# user_location                                                        None
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.6322
# text_human                              infrastructure_and_utility_damage
# text_human_conf                                                    0.6322
#
#                                                                       492
# id                                                     931898198569996288  \
# text                    #Iran Daily: US Treasury Blocks Donations for ...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sat Nov 18 14:53:39 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                             [Iran]
# entities_urls                                                        True
# user_location                                                        None
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.6732
# text_human                         rescue_volunteering_or_donation_effort
# text_human_conf                                                    0.6732
#
#                                                                       493
# id                                                     931925410224529410  \
# text                    #Kurdish children's situation after the #earth...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sat Nov 18 16:41:46 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                        [Kurdish, earthquake, Iran]
# entities_urls                                                       False
# user_location                                                        Iraq
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                                           affected_individuals
# text_human_conf                                                       1.0
#
#                                                                       494
# id                                                     932000082072948736  \
# text                    #IRAN'S #EARTHQUAKE EXPOSES #POLITICAL RIFTS A...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sat Nov 18 21:38:29 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text          [IRAN, EARTHQUAKE, POLITICAL, GOVERNANCE]
# entities_urls                                                        True
# user_location                                              Washington, DC
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                     0.6827
# text_human                                     other_relevant_information
# text_human_conf                                                    0.6827
#
#                                                                       495
# id                                                     932027639589507072
# text                    Victims of last week's earthquake gather outdo...
# favorite_count                                                          0
# retweet_count                                                           0
# possibly_sensitive                                                  False
# created_at                                 Sat Nov 18 23:28:00 +0000 2017
# is_quote_status                                                     False
# entities_hashtags_text                                             [Iran]
# entities_urls                                                       False
# user_location                                        Melbourne, Australia
# reply_count                                                             0
# quote_count                                                             0
# text_info                                                     informative
# text_info_conf                                                        1.0
# text_human                                           affected_individuals
# text_human_conf                                                       1.0
#
# [16 rows x 496 columns]

# %%
new_irma.shape
# Out:
# (496, 16)

# %% [markdown]
# Se procede a visualizar estos valores para poder analizarlos.
#
# Primero se analiza la cantidad de citas, favoritos, respuestas y retweets, observandolo como histogramas y sus valores ¿?.

# %%
def hist_interaction(df):
    print(df[['quote_count', 'favorite_count', 'reply_count', 'retweet_count']].describe())
    new_df = df[df['retweet_count'] > 50]
    new_df[['quote_count', 'favorite_count', 'reply_count', 'retweet_count']].hist()

hist_interaction(new_irma)
# Out:
#        quote_count  favorite_count  reply_count  retweet_count
# count   496.000000      496.000000   496.000000     496.000000
# mean      0.229839        2.125000     0.252016       2.338710
# std       1.409777       11.732563     1.770407      12.045796
# min       0.000000        0.000000     0.000000       0.000000
# 25%       0.000000        0.000000     0.000000       0.000000
# 50%       0.000000        0.000000     0.000000       0.000000
# 75%       0.000000        0.000000     0.000000       0.000000
# max      17.000000      133.000000    30.000000     124.000000

# %% [markdown]
# Se intenta contabilizar el resto de los valores donde se permite, como si el tweet es sensitivo, si es una cita o si tiene un url anexado.

# %%
def count_booleans(df):
    valores_T = 0
    valores_F = 0
    quoteable = 0
    not_quotable = 0
    url = 0
    urlnt = 0

    for i in range(df.shape[0]):
        if df["possibly_sensitive"][i]:
            valores_T +=1
        else:
            valores_F +=1

        if df["is_quote_status"][i]:
            quoteable += 1
        else:
            not_quotable += 1        

        if df["entities_urls"][i]:
            url += 1
        else:
            urlnt += 1

    plt.bar(["Posible Sensitivo","Posible no Sensitivo"],[valores_T, valores_F])
    plt.show()

    plt.bar(["Es Quote","No Es Quote"],[quoteable, not_quotable])
    plt.show()

    plt.bar(["Url Anexado","Url no Anexado"],[url, urlnt])
    plt.show()

count_booleans(new_irma)

# %% [markdown]
# Se procede a analizar los tweets si son informativos y si son humanitarios. Se separan en grupos según el valor 'conf'. Si 'conf' es 1, se grafican los valores como tal. Si 'conf' es menor a 1, se gráfica junto al promedio de conf.

# %%
def info_and_human(df):
    
    #se copia la dataframe
    df_info = df.copy()
    df_human = df.copy()

    #se borran los archivos NaN correspondientes
    df_info = df_info[df_info['text_info'].notna()]
    df_info = df_info[df_info['text_info_conf'].notna()]
    df_human = df_human[df_human['text_human'].notna()]
    df_human = df_human[df_human['text_human_conf'].notna()]

    #se reinicia la index si necesario
    df_info.reset_index(inplace=True, drop=True)
    df_human.reset_index(inplace=True, drop=True)

    #se crea nueva id según index
    df_info["new_id"] = df_info.index
    df_human["new_id"] = df_human.index

    
    #se crean dataframes para separar conf=1 con conf<1
    info_confiable = df_info[["new_id", "id", "text_info", "text_info_conf"]].copy()
    info_casi_confiable = df_info[["new_id", "id", "text_info", "text_info_conf"]].copy()

    wanted = []
    not_wanted = []

    i = 0
    while i < info_confiable.shape[0]:
        #print(info_confiable["text_info_conf"][i])
        if info_confiable["text_info_conf"][i] < 1:
            not_wanted.append(info_confiable["new_id"][i])
        else:
            wanted.append(info_confiable["new_id"][i])
        i += 1


    for j in not_wanted:
        info_confiable = info_confiable.drop(info_confiable[info_confiable["new_id"]==j].index)

    for k in wanted:
        info_casi_confiable = info_casi_confiable.drop(info_casi_confiable[info_casi_confiable["new_id"]==k].index)


    #se crean dataframes para separar conf=1 con conf<1
    human_confiable = df_human[["new_id", "id", "text_human", "text_human_conf"]].copy()
    human_casi_confiable = df_human[["new_id", "id", "text_human", "text_human_conf"]].copy()

    hwanted = []
    not_hwanted = []

    i = 0
    while i < human_confiable.shape[0]:
        #print(info_confiable["text_info_conf"][i])
        if human_confiable["text_human_conf"][i] < 1:
            not_hwanted.append(human_confiable["new_id"][i])
        else:
            hwanted.append(human_confiable["new_id"][i])
        i += 1


    for j in not_hwanted:
        human_confiable = human_confiable.drop(human_confiable[human_confiable["new_id"]==j].index)

    for k in hwanted:
        human_casi_confiable = human_casi_confiable.drop(human_casi_confiable[human_casi_confiable["new_id"]==k].index)


    valores_info_confiable = info_confiable["text_info"].value_counts()

    plt.bar(valores_info_confiable.index, valores_info_confiable.values)

    plt.xlabel("")
    plt.ylabel("")
    plt.title("")

    plt.show()

    valores_human_confiable = human_confiable["text_human"].value_counts()

    plt.bar(valores_human_confiable.index, valores_human_confiable.values)

    for i, v in enumerate(valores_human_confiable.values):
        plt.text(i, v + 1, str(v), ha="center")

    plt.xlabel("")
    plt.ylabel("")
    plt.title("")

    plt.xticks(rotation=90)

    plt.show()


    # calculate counts and means
    counts = info_casi_confiable['text_info'].value_counts().sort_index()
    means = info_casi_confiable.groupby('text_info')['text_info_conf'].mean().sort_index()

    # plot the bar chart
    fig, ax = plt.subplots(figsize=(8,6))
    counts.plot(kind='bar', color='blue', width=0.4, position=0, ax=ax)
    means.plot(kind='bar', color='red', width=0.4, position=1, ax=ax)

    # add labels
    ax.set_xlabel('Categorical Value')
    ax.set_ylabel('Count / Mean Reliability')
    ax.set_title('Count and Mean Reliability by Categorical Value')

    # add value labels
    for i, count in enumerate(counts):
        ax.text(i-0.2, count+0.1, str(count), color='black', fontweight='bold')
    for i, mean in enumerate(means):
        ax.text(i+0.2, mean+0.02, f'{mean:.2f}', color='black', ha='center')

    # calculate counts and means
    counts = human_casi_confiable['text_human'].value_counts().sort_index()
    means = human_casi_confiable.groupby('text_human')['text_human_conf'].mean().sort_index()

    # plot the bar chart
    fig, ax = plt.subplots(figsize=(8,6))
    counts.plot(kind='bar', color='blue', width=0.4, position=0, ax=ax)
    means.plot(kind='bar', color='red', width=0.4, position=1, ax=ax)

    # add labels
    ax.set_xlabel('Categorical Value')
    ax.set_ylabel('Count / Mean Reliability')
    ax.set_title('Count and Mean Reliability by Categorical Value')

    # add value labels
    for i, count in enumerate(counts):
        ax.text(i-0.2, count+0.1, str(count), color='black', fontweight='bold')
    for i, mean in enumerate(means):
        ax.text(i+0.2, mean+0.02, f'{mean:.2f}', color='black', ha='center')

info_and_human(new_irma)

# %% [markdown]
# Se procede a observar el texto de cada tweet. Se contabilizan las palabras usadas para buscar las más repetidas.

# %%
def count_words(L, n):
    words = []
    for text in list(L): 
        for word in str(text).split():
            #Aca se filtran las palabras que se repiten con mayusculas
            wl = re.sub(r'[\W_]+', '', word.lower())
            # california. -> california
            if word in ['US','USA', 'usa', 'Usa']:
                words.append('USA')
            
            elif wl == "":   
                pass
        
            elif word.lower()[:-2] == "'s":
                words.append(wl[0:-1])

            elif word.lower() != wl:
                words.append(wl)
    
            else:
                words.append(word.lower())

    counter_words = Counter(words)
    pairs = counter_words.most_common(n)
    return pairs

def filter_count_words(L,n):
    stop_words = set(stopwords.words('english'))
    stop_words.add('-')
    stop_words.add('&amp;')
    stop_words.add('|')
    a=count_words(L,n)
    filtered = []
    for word in range(len(a)-1):
        if a[word][0].lower() not in stop_words:
            filtered.append(a[word])
    return filtered

def graficar_palabras(pares):
    words = [par[0] for par in pares]
    frequencies = [par[1] for par in pares]
    
    fig, ax = plt.subplots()

    ax.bar(words, frequencies)
    ax.set_xlabel('Palabras')
    ax.set_ylabel('Frecuencia')
    ax.set_title('Frecuencia de palabras')
    ax.legend(['Frecuencia'])    
    ax.tick_params(axis='x', labelrotation=90)  
    fig.set_size_inches(15, 6)
    plt.show()

graficar_palabras(filter_count_words(irma['text'], 90))
